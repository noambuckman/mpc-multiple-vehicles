# %%
# %load_ext autoreload
# %autoreload 2
    
import src.multiagent_mpc as mpc
import src.traffic_world as tw
import src.car_plotting_multiple as cmplot
import glob
import argparse
import json
import pickle
import os
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
list_of_logs = glob.glob('/home/nbuckman/mpc_results/negsvo_tx2/*')

# %%
list_of_logs
# Out:
# ['/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_10_03-04-2021-130848',
#  '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_15_03-04-2021-130849',
#  '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_14_03-04-2021-130849',
#  '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_17_03-04-2021-130849',
#  '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_18_03-04-2021-130849',
#  '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_11_03-04-2021-130848',
#  '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_16_03-04-2021-130849',
#  '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_19_03-04-2021-130849',
#  '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_12_03-04-2021-130848',
#  '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_13_03-04-2021-130849']

# %%
# Arguments
camera_speed = -1
shape = 'image'
svo_colors = 1
n_workers = 8
fps = 16

LOG_DIRECTORY = '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_10_03-04-2021-130848/'

VEHICLE_PATH = LOG_DIRECTORY + 'ambulance.p'
OTHER_VEHICLE_PATH = LOG_DIRECTORY + 'other_vehicles.p'
TRAJ_PATH = LOG_DIRECTORY + 'trajectories.npy'
PARAMS_PATH = LOG_DIRECTORY + 'params.json'
WORLD_PATH = LOG_DIRECTORY + 'world.p'


trajectory = np.load(open(TRAJ_PATH,'rb'))
xamb = trajectory[0, :, :]
xothers = trajectory[1:, :, :]

log_string = LOG_DIRECTORY.split('/')[-2]
VIDEO_OUT_PATH = LOG_DIRECTORY + log_string + '.mp4'


# generate pictures for animation


# Load data
with open(PARAMS_PATH) as fp:
    params = json.load(fp)

response_vehicle = pickle.load(open(VEHICLE_PATH,'rb'))
other_vehicles = pickle.load(open(OTHER_VEHICLE_PATH,'rb')) #TODO:  save all the vehicles in one file
#
try:
    world = pickle.load(open(WORLD_PATH,'rb'))
except FileNotFoundError:
    WORLD_PATH = LOG_DIRECTORY + 'data/world.p'
    world = pickle.load(open(WORLD_PATH,'rb'))
    
    
    
# Prep a temp image directory


if camera_speed == -1:
    camera_speed = np.mean(xamb[4,:])

if svo_colors == 1:
    svo = []
    for veh in other_vehicles:
        if hasattr(veh, "theta_ij"):
            svo += [veh.theta_ij[-1]]
        else:
            svo += [veh.theta_iamb]
    car_colors = ['r' for i in range(len(svo))]
    for i in range(len(svo)):
        if svo[i] < np.pi/8.0:
            car_colors[i] = 'red'
        elif np.pi/8 <= svo[i] <= 3*np.pi/8.0:
            car_colors[i] = 'purple'
        elif np.pi/8 <= svo[i] <= np.pi/2.0:
            car_colors[i] = 'blue'
else:
    car_colors = None



IMG_DIR = LOG_DIRECTORY + 'temp/'
print("Saving photos to %s..."%(IMG_DIR))

os.makedirs(IMG_DIR, exist_ok=True)    
for f in glob.glob(os.path.join(IMG_DIR, "*.png")):
    os.remove(f)
try:
    os.remove(VIDEO_OUT_PATH)
except OSError:
    pass

cmplot.plot_cars(world, response_vehicle, xamb, [xothers[i,:,:] for i in range(xothers.shape[0])],
                IMG_DIR, shape, camera_speed, None, car_colors, n_workers)              

outfile = cmplot.animate(IMG_DIR, VIDEO_OUT_PATH, fps)

vid_directory = '/home/nbuckman/mpc-vids/'
cmd = 'cp %s %s'%(VIDEO_OUT_PATH, vid_directory)
os.system(cmd)


from IPython.display import Video

Video(outfile, embed=True, width=1024)
# Out:
# Saving photos to /home/nbuckman/mpc_results/negsvo_tx2/neg_svo_10_03-04-2021-130848/temp/...
# HBox(children=(FloatProgress(value=0.0, max=301.0), HTML(value='')))
# <video controls  width="1024" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# Arguments
camera_speed = -1
shape = 'image'
svo_colors = 1
n_workers = 8
fps = 16

LOG_DIRECTORY = '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_11_03-04-2021-130848/'

VEHICLE_PATH = LOG_DIRECTORY + 'ambulance.p'
OTHER_VEHICLE_PATH = LOG_DIRECTORY + 'other_vehicles.p'
TRAJ_PATH = LOG_DIRECTORY + 'trajectories.npy'
PARAMS_PATH = LOG_DIRECTORY + 'params.json'
WORLD_PATH = LOG_DIRECTORY + 'world.p'


trajectory = np.load(open(TRAJ_PATH,'rb'))
xamb = trajectory[0, :, :]
xothers = trajectory[1:, :, :]

log_string = LOG_DIRECTORY.split('/')[-2]
VIDEO_OUT_PATH = LOG_DIRECTORY + log_string + '.mp4'


# generate pictures for animation


# Load data
with open(PARAMS_PATH) as fp:
    params = json.load(fp)

response_vehicle = pickle.load(open(VEHICLE_PATH,'rb'))
other_vehicles = pickle.load(open(OTHER_VEHICLE_PATH,'rb')) #TODO:  save all the vehicles in one file
#
try:
    world = pickle.load(open(WORLD_PATH,'rb'))
except FileNotFoundError:
    WORLD_PATH = LOG_DIRECTORY + 'data/world.p'
    world = pickle.load(open(WORLD_PATH,'rb'))
    
    
    
# Prep a temp image directory


if camera_speed == -1:
    camera_speed = np.mean(xamb[4,:])

if svo_colors == 1:
    svo = []
    for veh in other_vehicles:
        if hasattr(veh, "theta_ij"):
            svo += [veh.theta_ij[-1]]
        else:
            svo += [veh.theta_iamb]
    car_colors = ['r' for i in range(len(svo))]
    for i in range(len(svo)):
        if svo[i] < np.pi/8.0:
            car_colors[i] = 'red'
        elif np.pi/8 <= svo[i] <= 3*np.pi/8.0:
            car_colors[i] = 'purple'
        elif np.pi/8 <= svo[i] <= np.pi/2.0:
            car_colors[i] = 'blue'
else:
    car_colors = None



IMG_DIR = LOG_DIRECTORY + 'temp/'
print("Saving photos to %s..."%(IMG_DIR))

os.makedirs(IMG_DIR, exist_ok=True)    
for f in glob.glob(os.path.join(IMG_DIR, "*.png")):
    os.remove(f)
try:
    os.remove(VIDEO_OUT_PATH)
except OSError:
    pass

cmplot.plot_cars(world, response_vehicle, xamb, [xothers[i,:,:] for i in range(xothers.shape[0])],
                IMG_DIR, shape, camera_speed, None, car_colors, n_workers)              

outfile = cmplot.animate(IMG_DIR, VIDEO_OUT_PATH, fps)

vid_directory = '/home/nbuckman/mpc-vids/'
cmd = 'cp %s %s'%(VIDEO_OUT_PATH, vid_directory)
os.system(cmd)


from IPython.display import Video

Video(outfile, embed=True, width=1024)
# Out:
# Saving photos to /home/nbuckman/mpc_results/negsvo_tx2/neg_svo_11_03-04-2021-130848/temp/...
# HBox(children=(FloatProgress(value=0.0, max=301.0), HTML(value='')))
# <video controls  width="1024" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# Arguments
camera_speed = -1
shape = 'image'
svo_colors = 1
n_workers = 8
fps = 16

LOG_DIRECTORY = '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_12_03-04-2021-130848/'

VEHICLE_PATH = LOG_DIRECTORY + 'ambulance.p'
OTHER_VEHICLE_PATH = LOG_DIRECTORY + 'other_vehicles.p'
TRAJ_PATH = LOG_DIRECTORY + 'trajectories.npy'
PARAMS_PATH = LOG_DIRECTORY + 'params.json'
WORLD_PATH = LOG_DIRECTORY + 'world.p'


trajectory = np.load(open(TRAJ_PATH,'rb'))
xamb = trajectory[0, :, :]
xothers = trajectory[1:, :, :]

log_string = LOG_DIRECTORY.split('/')[-2]
VIDEO_OUT_PATH = LOG_DIRECTORY + log_string + '.mp4'


# generate pictures for animation


# Load data
with open(PARAMS_PATH) as fp:
    params = json.load(fp)

response_vehicle = pickle.load(open(VEHICLE_PATH,'rb'))
other_vehicles = pickle.load(open(OTHER_VEHICLE_PATH,'rb')) #TODO:  save all the vehicles in one file
#
try:
    world = pickle.load(open(WORLD_PATH,'rb'))
except FileNotFoundError:
    WORLD_PATH = LOG_DIRECTORY + 'data/world.p'
    world = pickle.load(open(WORLD_PATH,'rb'))
    
    
    
# Prep a temp image directory


if camera_speed == -1:
    camera_speed = np.mean(xamb[4,:])

if svo_colors == 1:
    svo = []
    for veh in other_vehicles:
        if hasattr(veh, "theta_ij"):
            svo += [veh.theta_ij[-1]]
        else:
            svo += [veh.theta_iamb]
    car_colors = ['r' for i in range(len(svo))]
    for i in range(len(svo)):
        if svo[i] < np.pi/8.0:
            car_colors[i] = 'red'
        elif np.pi/8 <= svo[i] <= 3*np.pi/8.0:
            car_colors[i] = 'purple'
        elif np.pi/8 <= svo[i] <= np.pi/2.0:
            car_colors[i] = 'blue'
else:
    car_colors = None



IMG_DIR = LOG_DIRECTORY + 'temp/'
print("Saving photos to %s..."%(IMG_DIR))

os.makedirs(IMG_DIR, exist_ok=True)    
for f in glob.glob(os.path.join(IMG_DIR, "*.png")):
    os.remove(f)
try:
    os.remove(VIDEO_OUT_PATH)
except OSError:
    pass

cmplot.plot_cars(world, response_vehicle, xamb, [xothers[i,:,:] for i in range(xothers.shape[0])],
                IMG_DIR, shape, camera_speed, None, car_colors, n_workers)              

outfile = cmplot.animate(IMG_DIR, VIDEO_OUT_PATH, fps)

vid_directory = '/home/nbuckman/mpc-vids/'
cmd = 'cp %s %s'%(VIDEO_OUT_PATH, vid_directory)
os.system(cmd)


from IPython.display import Video

Video(outfile, embed=True, width=1024)
# Out:
# Saving photos to /home/nbuckman/mpc_results/negsvo_tx2/neg_svo_12_03-04-2021-130848/temp/...
# HBox(children=(FloatProgress(value=0.0, max=301.0), HTML(value='')))
# <video controls  width="1024" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# Arguments
camera_speed = -1
shape = 'image'
svo_colors = 1
n_workers = 8
fps = 16

LOG_DIRECTORY = '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_13_03-04-2021-130848/'

VEHICLE_PATH = LOG_DIRECTORY + 'ambulance.p'
OTHER_VEHICLE_PATH = LOG_DIRECTORY + 'other_vehicles.p'
TRAJ_PATH = LOG_DIRECTORY + 'trajectories.npy'
PARAMS_PATH = LOG_DIRECTORY + 'params.json'
WORLD_PATH = LOG_DIRECTORY + 'world.p'


trajectory = np.load(open(TRAJ_PATH,'rb'))
xamb = trajectory[0, :, :]
xothers = trajectory[1:, :, :]

log_string = LOG_DIRECTORY.split('/')[-2]
VIDEO_OUT_PATH = LOG_DIRECTORY + log_string + '.mp4'


# generate pictures for animation


# Load data
with open(PARAMS_PATH) as fp:
    params = json.load(fp)

response_vehicle = pickle.load(open(VEHICLE_PATH,'rb'))
other_vehicles = pickle.load(open(OTHER_VEHICLE_PATH,'rb')) #TODO:  save all the vehicles in one file
#
try:
    world = pickle.load(open(WORLD_PATH,'rb'))
except FileNotFoundError:
    WORLD_PATH = LOG_DIRECTORY + 'data/world.p'
    world = pickle.load(open(WORLD_PATH,'rb'))
    
    
    
# Prep a temp image directory


if camera_speed == -1:
    camera_speed = np.mean(xamb[4,:])

if svo_colors == 1:
    svo = []
    for veh in other_vehicles:
        if hasattr(veh, "theta_ij"):
            svo += [veh.theta_ij[-1]]
        else:
            svo += [veh.theta_iamb]
    car_colors = ['r' for i in range(len(svo))]
    for i in range(len(svo)):
        if svo[i] < np.pi/8.0:
            car_colors[i] = 'red'
        elif np.pi/8 <= svo[i] <= 3*np.pi/8.0:
            car_colors[i] = 'purple'
        elif np.pi/8 <= svo[i] <= np.pi/2.0:
            car_colors[i] = 'blue'
else:
    car_colors = None



IMG_DIR = LOG_DIRECTORY + 'temp/'
print("Saving photos to %s..."%(IMG_DIR))

os.makedirs(IMG_DIR, exist_ok=True)    
for f in glob.glob(os.path.join(IMG_DIR, "*.png")):
    os.remove(f)
try:
    os.remove(VIDEO_OUT_PATH)
except OSError:
    pass

cmplot.plot_cars(world, response_vehicle, xamb, [xothers[i,:,:] for i in range(xothers.shape[0])],
                IMG_DIR, shape, camera_speed, None, car_colors, n_workers)              

outfile = cmplot.animate(IMG_DIR, VIDEO_OUT_PATH, fps)

vid_directory = '/home/nbuckman/mpc-vids/'
cmd = 'cp %s %s'%(VIDEO_OUT_PATH, vid_directory)
os.system(cmd)


from IPython.display import Video

Video(outfile, embed=True, width=1024)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-38-a03ec425556d> in <module>
#      15
#      16
# ---> 17 trajectory = np.load(open(TRAJ_PATH,'rb'))
#      18 xamb = trajectory[0, :, :]
#      19 xothers = trajectory[1:, :, :]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_13_03-04-2021-130848/trajectories.npy'

# %%
# Arguments
camera_speed = -1
shape = 'image'
svo_colors = 1
n_workers = 8
fps = 16

LOG_DIRECTORY = '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_14_03-04-2021-130848/'

VEHICLE_PATH = LOG_DIRECTORY + 'ambulance.p'
OTHER_VEHICLE_PATH = LOG_DIRECTORY + 'other_vehicles.p'
TRAJ_PATH = LOG_DIRECTORY + 'trajectories.npy'
PARAMS_PATH = LOG_DIRECTORY + 'params.json'
WORLD_PATH = LOG_DIRECTORY + 'world.p'


trajectory = np.load(open(TRAJ_PATH,'rb'))
xamb = trajectory[0, :, :]
xothers = trajectory[1:, :, :]

log_string = LOG_DIRECTORY.split('/')[-2]
VIDEO_OUT_PATH = LOG_DIRECTORY + log_string + '.mp4'


# generate pictures for animation


# Load data
with open(PARAMS_PATH) as fp:
    params = json.load(fp)

response_vehicle = pickle.load(open(VEHICLE_PATH,'rb'))
other_vehicles = pickle.load(open(OTHER_VEHICLE_PATH,'rb')) #TODO:  save all the vehicles in one file
#
try:
    world = pickle.load(open(WORLD_PATH,'rb'))
except FileNotFoundError:
    WORLD_PATH = LOG_DIRECTORY + 'data/world.p'
    world = pickle.load(open(WORLD_PATH,'rb'))
    
    
    
# Prep a temp image directory


if camera_speed == -1:
    camera_speed = np.mean(xamb[4,:])

if svo_colors == 1:
    svo = []
    for veh in other_vehicles:
        if hasattr(veh, "theta_ij"):
            svo += [veh.theta_ij[-1]]
        else:
            svo += [veh.theta_iamb]
    car_colors = ['r' for i in range(len(svo))]
    for i in range(len(svo)):
        if svo[i] < np.pi/8.0:
            car_colors[i] = 'red'
        elif np.pi/8 <= svo[i] <= 3*np.pi/8.0:
            car_colors[i] = 'purple'
        elif np.pi/8 <= svo[i] <= np.pi/2.0:
            car_colors[i] = 'blue'
else:
    car_colors = None



IMG_DIR = LOG_DIRECTORY + 'temp/'
print("Saving photos to %s..."%(IMG_DIR))

os.makedirs(IMG_DIR, exist_ok=True)    
for f in glob.glob(os.path.join(IMG_DIR, "*.png")):
    os.remove(f)
try:
    os.remove(VIDEO_OUT_PATH)
except OSError:
    pass

cmplot.plot_cars(world, response_vehicle, xamb, [xothers[i,:,:] for i in range(xothers.shape[0])],
                IMG_DIR, shape, camera_speed, None, car_colors, n_workers)              

outfile = cmplot.animate(IMG_DIR, VIDEO_OUT_PATH, fps)

vid_directory = '/home/nbuckman/mpc-vids/'
cmd = 'cp %s %s'%(VIDEO_OUT_PATH, vid_directory)
os.system(cmd)


from IPython.display import Video

Video(outfile, embed=True, width=1024)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-39-a7b07e88dd6e> in <module>
#      15
#      16
# ---> 17 trajectory = np.load(open(TRAJ_PATH,'rb'))
#      18 xamb = trajectory[0, :, :]
#      19 xothers = trajectory[1:, :, :]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_14_03-04-2021-130848/trajectories.npy'

# %%
# Arguments
camera_speed = -1
shape = 'image'
svo_colors = 1
n_workers = 8
fps = 16

LOG_DIRECTORY = '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_15_03-04-2021-130848/'

VEHICLE_PATH = LOG_DIRECTORY + 'ambulance.p'
OTHER_VEHICLE_PATH = LOG_DIRECTORY + 'other_vehicles.p'
TRAJ_PATH = LOG_DIRECTORY + 'trajectories.npy'
PARAMS_PATH = LOG_DIRECTORY + 'params.json'
WORLD_PATH = LOG_DIRECTORY + 'world.p'


trajectory = np.load(open(TRAJ_PATH,'rb'))
xamb = trajectory[0, :, :]
xothers = trajectory[1:, :, :]

log_string = LOG_DIRECTORY.split('/')[-2]
VIDEO_OUT_PATH = LOG_DIRECTORY + log_string + '.mp4'


# generate pictures for animation


# Load data
with open(PARAMS_PATH) as fp:
    params = json.load(fp)

response_vehicle = pickle.load(open(VEHICLE_PATH,'rb'))
other_vehicles = pickle.load(open(OTHER_VEHICLE_PATH,'rb')) #TODO:  save all the vehicles in one file
#
try:
    world = pickle.load(open(WORLD_PATH,'rb'))
except FileNotFoundError:
    WORLD_PATH = LOG_DIRECTORY + 'data/world.p'
    world = pickle.load(open(WORLD_PATH,'rb'))
    
    
    
# Prep a temp image directory


if camera_speed == -1:
    camera_speed = np.mean(xamb[4,:])

if svo_colors == 1:
    svo = []
    for veh in other_vehicles:
        if hasattr(veh, "theta_ij"):
            svo += [veh.theta_ij[-1]]
        else:
            svo += [veh.theta_iamb]
    car_colors = ['r' for i in range(len(svo))]
    for i in range(len(svo)):
        if svo[i] < np.pi/8.0:
            car_colors[i] = 'red'
        elif np.pi/8 <= svo[i] <= 3*np.pi/8.0:
            car_colors[i] = 'purple'
        elif np.pi/8 <= svo[i] <= np.pi/2.0:
            car_colors[i] = 'blue'
else:
    car_colors = None



IMG_DIR = LOG_DIRECTORY + 'temp/'
print("Saving photos to %s..."%(IMG_DIR))

os.makedirs(IMG_DIR, exist_ok=True)    
for f in glob.glob(os.path.join(IMG_DIR, "*.png")):
    os.remove(f)
try:
    os.remove(VIDEO_OUT_PATH)
except OSError:
    pass

cmplot.plot_cars(world, response_vehicle, xamb, [xothers[i,:,:] for i in range(xothers.shape[0])],
                IMG_DIR, shape, camera_speed, None, car_colors, n_workers)              

outfile = cmplot.animate(IMG_DIR, VIDEO_OUT_PATH, fps)

vid_directory = '/home/nbuckman/mpc-vids/'
cmd = 'cp %s %s'%(VIDEO_OUT_PATH, vid_directory)
os.system(cmd)


from IPython.display import Video

Video(outfile, embed=True, width=1024)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-48d456944e8b> in <module>
#      15
#      16
# ---> 17 trajectory = np.load(open(TRAJ_PATH,'rb'))
#      18 xamb = trajectory[0, :, :]
#      19 xothers = trajectory[1:, :, :]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_15_03-04-2021-130848/trajectories.npy'

# %%
# Arguments
camera_speed = -1
shape = 'image'
svo_colors = 1
n_workers = 8
fps = 16

LOG_DIRECTORY = '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_16_03-04-2021-130848/'

VEHICLE_PATH = LOG_DIRECTORY + 'ambulance.p'
OTHER_VEHICLE_PATH = LOG_DIRECTORY + 'other_vehicles.p'
TRAJ_PATH = LOG_DIRECTORY + 'trajectories.npy'
PARAMS_PATH = LOG_DIRECTORY + 'params.json'
WORLD_PATH = LOG_DIRECTORY + 'world.p'


trajectory = np.load(open(TRAJ_PATH,'rb'))
xamb = trajectory[0, :, :]
xothers = trajectory[1:, :, :]

log_string = LOG_DIRECTORY.split('/')[-2]
VIDEO_OUT_PATH = LOG_DIRECTORY + log_string + '.mp4'


# generate pictures for animation


# Load data
with open(PARAMS_PATH) as fp:
    params = json.load(fp)

response_vehicle = pickle.load(open(VEHICLE_PATH,'rb'))
other_vehicles = pickle.load(open(OTHER_VEHICLE_PATH,'rb')) #TODO:  save all the vehicles in one file
#
try:
    world = pickle.load(open(WORLD_PATH,'rb'))
except FileNotFoundError:
    WORLD_PATH = LOG_DIRECTORY + 'data/world.p'
    world = pickle.load(open(WORLD_PATH,'rb'))
    
    
    
# Prep a temp image directory


if camera_speed == -1:
    camera_speed = np.mean(xamb[4,:])

if svo_colors == 1:
    svo = []
    for veh in other_vehicles:
        if hasattr(veh, "theta_ij"):
            svo += [veh.theta_ij[-1]]
        else:
            svo += [veh.theta_iamb]
    car_colors = ['r' for i in range(len(svo))]
    for i in range(len(svo)):
        if svo[i] < np.pi/8.0:
            car_colors[i] = 'red'
        elif np.pi/8 <= svo[i] <= 3*np.pi/8.0:
            car_colors[i] = 'purple'
        elif np.pi/8 <= svo[i] <= np.pi/2.0:
            car_colors[i] = 'blue'
else:
    car_colors = None



IMG_DIR = LOG_DIRECTORY + 'temp/'
print("Saving photos to %s..."%(IMG_DIR))

os.makedirs(IMG_DIR, exist_ok=True)    
for f in glob.glob(os.path.join(IMG_DIR, "*.png")):
    os.remove(f)
try:
    os.remove(VIDEO_OUT_PATH)
except OSError:
    pass

cmplot.plot_cars(world, response_vehicle, xamb, [xothers[i,:,:] for i in range(xothers.shape[0])],
                IMG_DIR, shape, camera_speed, None, car_colors, n_workers)              

outfile = cmplot.animate(IMG_DIR, VIDEO_OUT_PATH, fps)

vid_directory = '/home/nbuckman/mpc-vids/'
cmd = 'cp %s %s'%(VIDEO_OUT_PATH, vid_directory)
os.system(cmd)


from IPython.display import Video

Video(outfile, embed=True, width=1024)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-41-1f9281cb14a7> in <module>
#      15
#      16
# ---> 17 trajectory = np.load(open(TRAJ_PATH,'rb'))
#      18 xamb = trajectory[0, :, :]
#      19 xothers = trajectory[1:, :, :]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_16_03-04-2021-130848/trajectories.npy'

# %%
# Arguments
camera_speed = -1
shape = 'image'
svo_colors = 1
n_workers = 8
fps = 16

LOG_DIRECTORY = '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_17_03-04-2021-130848/'

VEHICLE_PATH = LOG_DIRECTORY + 'ambulance.p'
OTHER_VEHICLE_PATH = LOG_DIRECTORY + 'other_vehicles.p'
TRAJ_PATH = LOG_DIRECTORY + 'trajectories.npy'
PARAMS_PATH = LOG_DIRECTORY + 'params.json'
WORLD_PATH = LOG_DIRECTORY + 'world.p'


trajectory = np.load(open(TRAJ_PATH,'rb'))
xamb = trajectory[0, :, :]
xothers = trajectory[1:, :, :]

log_string = LOG_DIRECTORY.split('/')[-2]
VIDEO_OUT_PATH = LOG_DIRECTORY + log_string + '.mp4'


# generate pictures for animation


# Load data
with open(PARAMS_PATH) as fp:
    params = json.load(fp)

response_vehicle = pickle.load(open(VEHICLE_PATH,'rb'))
other_vehicles = pickle.load(open(OTHER_VEHICLE_PATH,'rb')) #TODO:  save all the vehicles in one file
#
try:
    world = pickle.load(open(WORLD_PATH,'rb'))
except FileNotFoundError:
    WORLD_PATH = LOG_DIRECTORY + 'data/world.p'
    world = pickle.load(open(WORLD_PATH,'rb'))
    
    
    
# Prep a temp image directory


if camera_speed == -1:
    camera_speed = np.mean(xamb[4,:])

if svo_colors == 1:
    svo = []
    for veh in other_vehicles:
        if hasattr(veh, "theta_ij"):
            svo += [veh.theta_ij[-1]]
        else:
            svo += [veh.theta_iamb]
    car_colors = ['r' for i in range(len(svo))]
    for i in range(len(svo)):
        if svo[i] < np.pi/8.0:
            car_colors[i] = 'red'
        elif np.pi/8 <= svo[i] <= 3*np.pi/8.0:
            car_colors[i] = 'purple'
        elif np.pi/8 <= svo[i] <= np.pi/2.0:
            car_colors[i] = 'blue'
else:
    car_colors = None



IMG_DIR = LOG_DIRECTORY + 'temp/'
print("Saving photos to %s..."%(IMG_DIR))

os.makedirs(IMG_DIR, exist_ok=True)    
for f in glob.glob(os.path.join(IMG_DIR, "*.png")):
    os.remove(f)
try:
    os.remove(VIDEO_OUT_PATH)
except OSError:
    pass

cmplot.plot_cars(world, response_vehicle, xamb, [xothers[i,:,:] for i in range(xothers.shape[0])],
                IMG_DIR, shape, camera_speed, None, car_colors, n_workers)              

outfile = cmplot.animate(IMG_DIR, VIDEO_OUT_PATH, fps)

vid_directory = '/home/nbuckman/mpc-vids/'
cmd = 'cp %s %s'%(VIDEO_OUT_PATH, vid_directory)
os.system(cmd)


from IPython.display import Video

Video(outfile, embed=True, width=1024)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-42-87a2060477c7> in <module>
#      15
#      16
# ---> 17 trajectory = np.load(open(TRAJ_PATH,'rb'))
#      18 xamb = trajectory[0, :, :]
#      19 xothers = trajectory[1:, :, :]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_17_03-04-2021-130848/trajectories.npy'

# %%
# Arguments
camera_speed = -1
shape = 'image'
svo_colors = 1
n_workers = 8
fps = 16

LOG_DIRECTORY = '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_18_03-04-2021-130848/'

VEHICLE_PATH = LOG_DIRECTORY + 'ambulance.p'
OTHER_VEHICLE_PATH = LOG_DIRECTORY + 'other_vehicles.p'
TRAJ_PATH = LOG_DIRECTORY + 'trajectories.npy'
PARAMS_PATH = LOG_DIRECTORY + 'params.json'
WORLD_PATH = LOG_DIRECTORY + 'world.p'


trajectory = np.load(open(TRAJ_PATH,'rb'))
xamb = trajectory[0, :, :]
xothers = trajectory[1:, :, :]

log_string = LOG_DIRECTORY.split('/')[-2]
VIDEO_OUT_PATH = LOG_DIRECTORY + log_string + '.mp4'


# generate pictures for animation


# Load data
with open(PARAMS_PATH) as fp:
    params = json.load(fp)

response_vehicle = pickle.load(open(VEHICLE_PATH,'rb'))
other_vehicles = pickle.load(open(OTHER_VEHICLE_PATH,'rb')) #TODO:  save all the vehicles in one file
#
try:
    world = pickle.load(open(WORLD_PATH,'rb'))
except FileNotFoundError:
    WORLD_PATH = LOG_DIRECTORY + 'data/world.p'
    world = pickle.load(open(WORLD_PATH,'rb'))
    
    
    
# Prep a temp image directory


if camera_speed == -1:
    camera_speed = np.mean(xamb[4,:])

if svo_colors == 1:
    svo = []
    for veh in other_vehicles:
        if hasattr(veh, "theta_ij"):
            svo += [veh.theta_ij[-1]]
        else:
            svo += [veh.theta_iamb]
    car_colors = ['r' for i in range(len(svo))]
    for i in range(len(svo)):
        if svo[i] < np.pi/8.0:
            car_colors[i] = 'red'
        elif np.pi/8 <= svo[i] <= 3*np.pi/8.0:
            car_colors[i] = 'purple'
        elif np.pi/8 <= svo[i] <= np.pi/2.0:
            car_colors[i] = 'blue'
else:
    car_colors = None



IMG_DIR = LOG_DIRECTORY + 'temp/'
print("Saving photos to %s..."%(IMG_DIR))

os.makedirs(IMG_DIR, exist_ok=True)    
for f in glob.glob(os.path.join(IMG_DIR, "*.png")):
    os.remove(f)
try:
    os.remove(VIDEO_OUT_PATH)
except OSError:
    pass

cmplot.plot_cars(world, response_vehicle, xamb, [xothers[i,:,:] for i in range(xothers.shape[0])],
                IMG_DIR, shape, camera_speed, None, car_colors, n_workers)              

outfile = cmplot.animate(IMG_DIR, VIDEO_OUT_PATH, fps)

vid_directory = '/home/nbuckman/mpc-vids/'
cmd = 'cp %s %s'%(VIDEO_OUT_PATH, vid_directory)
os.system(cmd)


from IPython.display import Video

Video(outfile, embed=True, width=1024)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-43-bbe02a63e319> in <module>
#      15
#      16
# ---> 17 trajectory = np.load(open(TRAJ_PATH,'rb'))
#      18 xamb = trajectory[0, :, :]
#      19 xothers = trajectory[1:, :, :]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_18_03-04-2021-130848/trajectories.npy'

# %%
# Arguments
camera_speed = -1
shape = 'image'
svo_colors = 1
n_workers = 8
fps = 16

LOG_DIRECTORY = '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_19_03-04-2021-130848/'

VEHICLE_PATH = LOG_DIRECTORY + 'ambulance.p'
OTHER_VEHICLE_PATH = LOG_DIRECTORY + 'other_vehicles.p'
TRAJ_PATH = LOG_DIRECTORY + 'trajectories.npy'
PARAMS_PATH = LOG_DIRECTORY + 'params.json'
WORLD_PATH = LOG_DIRECTORY + 'world.p'


trajectory = np.load(open(TRAJ_PATH,'rb'))
xamb = trajectory[0, :, :]
xothers = trajectory[1:, :, :]

log_string = LOG_DIRECTORY.split('/')[-2]
VIDEO_OUT_PATH = LOG_DIRECTORY + log_string + '.mp4'


# generate pictures for animation


# Load data
with open(PARAMS_PATH) as fp:
    params = json.load(fp)

response_vehicle = pickle.load(open(VEHICLE_PATH,'rb'))
other_vehicles = pickle.load(open(OTHER_VEHICLE_PATH,'rb')) #TODO:  save all the vehicles in one file
#
try:
    world = pickle.load(open(WORLD_PATH,'rb'))
except FileNotFoundError:
    WORLD_PATH = LOG_DIRECTORY + 'data/world.p'
    world = pickle.load(open(WORLD_PATH,'rb'))
    
    
    
# Prep a temp image directory


if camera_speed == -1:
    camera_speed = np.mean(xamb[4,:])

if svo_colors == 1:
    svo = []
    for veh in other_vehicles:
        if hasattr(veh, "theta_ij"):
            svo += [veh.theta_ij[-1]]
        else:
            svo += [veh.theta_iamb]
    car_colors = ['r' for i in range(len(svo))]
    for i in range(len(svo)):
        if svo[i] < np.pi/8.0:
            car_colors[i] = 'red'
        elif np.pi/8 <= svo[i] <= 3*np.pi/8.0:
            car_colors[i] = 'purple'
        elif np.pi/8 <= svo[i] <= np.pi/2.0:
            car_colors[i] = 'blue'
else:
    car_colors = None



IMG_DIR = LOG_DIRECTORY + 'temp/'
print("Saving photos to %s..."%(IMG_DIR))

os.makedirs(IMG_DIR, exist_ok=True)    
for f in glob.glob(os.path.join(IMG_DIR, "*.png")):
    os.remove(f)
try:
    os.remove(VIDEO_OUT_PATH)
except OSError:
    pass

cmplot.plot_cars(world, response_vehicle, xamb, [xothers[i,:,:] for i in range(xothers.shape[0])],
                IMG_DIR, shape, camera_speed, None, car_colors, n_workers)              

outfile = cmplot.animate(IMG_DIR, VIDEO_OUT_PATH, fps)

vid_directory = '/home/nbuckman/mpc-vids/'
cmd = 'cp %s %s'%(VIDEO_OUT_PATH, vid_directory)
os.system(cmd)


from IPython.display import Video

Video(outfile, embed=True, width=1024)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-44-3f68a1abdb8c> in <module>
#      15
#      16
# ---> 17 trajectory = np.load(open(TRAJ_PATH,'rb'))
#      18 xamb = trajectory[0, :, :]
#      19 xothers = trajectory[1:, :, :]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/nbuckman/mpc_results/negsvo_tx2/neg_svo_19_03-04-2021-130848/trajectories.npy'
