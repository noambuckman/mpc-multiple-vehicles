# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os, sys
import numpy as np
import matplotlib.pyplot as plt

import casadi as cas

##### For viewing the videos in Jupyter Notebook
import io
import base64
from IPython.display import HTML

# from ..</src> import car_plotting
# from .import src.car_plotting
PROJECT_PATH = '/home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/'
sys.path.append(PROJECT_PATH)
import src.MPC_Casadi as mpc
import src.car_plotting as cplot
np.set_printoptions(precision=2)
# %matplotlib inline

# %% [markdown]
# # Vehicle Dynamics $\frac{d}{dt} \vec{x} = f(\vec{x}, \vec{u})$

# %% [markdown]
# def gen_x_next(x_k, u_k, dt):
#     k1 = f(x_k, u_k)
#     k2 = f(x_k+dt/2*k1, u_k)
#     k3 = f(x_k+dt/2*k2, u_k)
#     k4 = f(x_k+dt*k3,   u_k)
#     x_next = x_k + dt/6*(k1+2*k2+2*k3+k4)
#     return x_next
# # F = cas.Function('F',[x,u,t],[ode],)

# %% [markdown]
# #  States
#
# $\vec{x}$ = $[x, y, \phi, \delta, V, s]^T$
#
# $\vec{u}$ = $[\delta^u, v^u]^T$

# %% [markdown]
# # Discrete (integrated) dynamics $\vec{x}_{t+1} = F(\vec{x}_{t}, \vec{u}_{t})$

# %%
T = 10 #numbr of time horizons
dt = 0.1
N = int(T/dt) #Number of control intervals

# %% [markdown]
# # Problem Definition
# ### Parameterization of Desired Trajectory ($\vec{x}_d = f_d(s)$)

# %%
s = cas.MX.sym('s')
xd = s
yd = 0
phid = 0
des_traj = cas.vertcat(xd, yd, phid)
fd = cas.Function('fd',[s],[des_traj],['s'],['des_traj'])

# %%
#Globally true information
min_dist = 2 * (2 * .5**2)**.5

# initial_speed = 6.7 
initial_speed = 20 * 0.447 # m/s

# Initial Conditions
x0 = np.array([2*min_dist, 1.2*min_dist, 0, 0, initial_speed, 0]).T
x0_2 = np.array([2*min_dist, 0, .0, 0, initial_speed, 0]).T
x0_amb = np.array([0, 0.0, 0, 0, 1.1 * initial_speed , 0]).T

# %%
LANE_WIDTH = min_dist
xd2 = s
yd2 = LANE_WIDTH
phid = 0
des_traj2 = cas.vertcat(xd2, yd2, phid)
fd2 = cas.Function('fd',[s],[des_traj2],['s'],['des_traj2'])

# %% [markdown]
# ## IBR from Beginning

# %%
x1_MPC = mpc.MPC(dt)
x2_MPC = mpc.MPC(dt)
amb_MPC = mpc.MPC(dt)

x1_MPC.theta_iamb = 0
x2_MPC.theta_iamb =  0
amb_MPC.theta_iamb = 0


x1_MPC.k_final = 1.0
x2_MPC.k_final = 1.0
amb_MPC.k_final = 1.0


x1_MPC.k_s = -1.0
x2_MPC.k_s = -1.0

amb_MPC.theta_iamb = 0.0
amb_MPC.k_u_v = 0.10
# amb_MPC.k_u_change = 1.0
amb_MPC.k_s = -1.0
amb_MPC.max_v = 40 * 0.447 # m/s
amb_MPC.max_X_dev = 5.0


x2_MPC.fd = fd
amb_MPC.fd = fd
x1_MPC.fd = fd2


x1_MPC.min_y = -1.1 * LANE_WIDTH
x2_MPC.min_y = -1.1 * LANE_WIDTH
amb_MPC.min_y = -1.1 * LANE_WIDTH

# %%
ibr_sub_it = 1

# %%
optional_suffix = "_ibr_altru"
subdir_name = datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + optional_suffix
folder = "results/" + subdir_name + "/"
os.makedirs(folder)
os.makedirs(folder+"imgs/")
print(folder)
# Out:
# results/20200220-181343_ibr_altru/

# %%
u1 = np.zeros((2,N))
u2 = np.zeros((2,N))

# %%
ibr_sub_it = 1
n_total_round = 12
for n_round in range(n_total_round):
    brA = mpc.IterativeBestResponseMPC(amb_MPC, x1_MPC, x2_MPC)
    brA.generate_optimization(N, min_dist, fd, T, x0_amb, x0, x0_2,  2)
    brA.solve(u1, u2)
    print("A", brA.solution.value(brA.car1MPC.total_cost()))
    xamb, uamb, xamb_des, x1, u1, x1_des, x2, u2, x2_des = brA.get_solution()
    brA.save_state(folder + '%02d'%ibr_sub_it + "_a", x1, u1, x1_des, x2, u2, x2_des, xamb, uamb, xamb_des)
    ibr_sub_it+=1

    br2 = mpc.IterativeBestResponseMPC(x2_MPC, x1_MPC, amb_MPC )
    br2.generate_optimization(N, min_dist, fd, T, x0_2, x0, x0_amb, 2, slack=True)
    br2.solve(u1, uamb)
    x2, u2, x2_des, x1, u1, x1_des, xamb, uamb, xamb_des = br2.get_solution()
    print(br2.solution.value(br2.slack_cost))
    print("2", br2.solution.value(br2.car1MPC.total_cost()))
    br2.save_state(folder + '%02d'%ibr_sub_it + "_2", x1, u1, x1_des, x2, u2, x2_des, xamb, uamb, xamb_des)
    ibr_sub_it+=1

    br1 = mpc.IterativeBestResponseMPC(x1_MPC, x2_MPC, amb_MPC)
    br1.generate_optimization(N, min_dist, fd, T,  x0, x0_2, x0_amb, 2, slack=True)
    br1.solve(u2, uamb)
    x1, u1, x1_des, x2, u2, x2_des, xamb, uamb, xamb_des = br1.get_solution()
    print(br1.solution.value(br1.slack_cost))
    print("1", br1.solution.value(br1.car1MPC.total_cost()))
    br1.save_state(folder + '%02d'%ibr_sub_it + "_1", x1, u1, x1_des, x2, u2, x2_des, xamb, uamb, xamb_des)
    ibr_sub_it+=1
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  31.20ms (104.33us)  31.03ms (103.79us)       299
#        nlp_g  | 369.40ms (  1.24ms) 366.77ms (  1.23ms)       299
#     nlp_grad  |   3.98ms (  3.98ms)   3.94ms (  3.94ms)         1
#   nlp_grad_f  |  79.09ms (265.41us)  78.70ms (264.09us)       298
#   nlp_hess_l  |   4.40 s ( 14.87ms)   4.37 s ( 14.76ms)       296
#    nlp_jac_g  |   2.63 s (  8.82ms)   2.61 s (  8.76ms)       298
#        total  |  10.50 s ( 10.50 s)  10.43 s ( 10.43 s)         1
# A -8286.995747857616
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  30.09ms (179.10us)  30.08ms (179.04us)       168
#        nlp_g  | 211.62ms (  1.26ms) 210.83ms (  1.25ms)       168
#     nlp_grad  |   4.49ms (  4.49ms)   4.48ms (  4.48ms)         1
#   nlp_grad_f  |  79.28ms (514.77us)  79.19ms (514.25us)       154
#   nlp_hess_l  |   2.85 s ( 17.57ms)   2.84 s ( 17.51ms)       162
#    nlp_jac_g  |   1.48 s (  8.91ms)   1.47 s (  8.88ms)       166
#        total  |   6.78 s (  6.78 s)   6.75 s (  6.75 s)         1
# 4.3704009499589494e-08
# 2 -6661.564707004743
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  21.22ms (186.15us)  21.22ms (186.12us)       114
#        nlp_g  | 138.49ms (  1.21ms) 138.17ms (  1.21ms)       114
#     nlp_grad  |   4.40ms (  4.40ms)   4.38ms (  4.38ms)         1
#   nlp_grad_f  |  43.28ms (527.85us)  43.18ms (526.63us)        82
#   nlp_hess_l  |   1.58 s ( 17.71ms)   1.57 s ( 17.64ms)        89
#    nlp_jac_g  | 829.41ms (  8.92ms) 826.46ms (  8.89ms)        93
#        total  |   3.79 s (  3.79 s)   3.77 s (  3.77 s)         1
# 3.878803937677104e-10
# 1 -10305.191078982161
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  62.08ms (133.51us)  62.03ms (133.40us)       465
#        nlp_g  | 566.59ms (  1.22ms) 564.85ms (  1.21ms)       465
#     nlp_grad  |   4.15ms (  4.15ms)   4.14ms (  4.14ms)         1
#   nlp_grad_f  | 132.45ms (284.22us) 132.24ms (283.77us)       466
#   nlp_hess_l  |   6.85 s ( 14.76ms)   6.83 s ( 14.71ms)       464
#    nlp_jac_g  |   4.07 s (  8.72ms)   4.05 s (  8.69ms)       466
#        total  |  16.35 s ( 16.35 s)  16.29 s ( 16.29 s)         1
# A -12722.335814810676
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 190.59ms (226.08us) 190.62ms (226.13us)       843
#        nlp_g  |   1.05 s (  1.24ms)   1.05 s (  1.24ms)       843
#     nlp_grad  |   4.38ms (  4.38ms)   4.36ms (  4.36ms)         1
#   nlp_grad_f  | 357.30ms (543.00us) 356.49ms (541.77us)       658
#   nlp_hess_l  |  14.53 s ( 17.46ms)  14.47 s ( 17.40ms)       832
#    nlp_jac_g  |   7.40 s (  8.83ms)   7.38 s (  8.80ms)       838
#        total  |  33.74 s ( 33.74 s)  33.62 s ( 33.62 s)         1
# 4.03851278612653e-08
# 2 -9727.37739431481
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 223.11ms (223.56us) 222.78ms (223.22us)       998
#        nlp_g  |   1.24 s (  1.24ms)   1.24 s (  1.24ms)       998
#     nlp_grad  |   4.39ms (  4.39ms)   4.39ms (  4.39ms)         1
#   nlp_grad_f  | 474.73ms (550.10us) 473.51ms (548.68us)       863
#   nlp_hess_l  |  17.13 s ( 17.50ms)  17.07 s ( 17.43ms)       979
#    nlp_jac_g  |   8.73 s (  8.85ms)   8.70 s (  8.82ms)       987
#        total  |  43.30 s ( 43.30 s)  43.14 s ( 43.14 s)         1
# 1.1237639862328039e-10
# 1 -10310.185739070535
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  64.86ms (143.49us)  64.90ms (143.58us)       452
#        nlp_g  | 540.33ms (  1.20ms) 538.51ms (  1.19ms)       452
#     nlp_grad  |   4.29ms (  4.29ms)   4.27ms (  4.27ms)         1
#   nlp_grad_f  | 129.69ms (287.56us) 129.68ms (287.53us)       451
#   nlp_hess_l  |   6.59 s ( 14.67ms)   6.56 s ( 14.62ms)       449
#    nlp_jac_g  |   3.89 s (  8.64ms)   3.88 s (  8.60ms)       451
#        total  |  16.30 s ( 16.30 s)  16.24 s ( 16.24 s)         1
# A -11451.058909086072
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  53.33ms (225.03us)  53.20ms (224.48us)       237
#        nlp_g  | 283.27ms (  1.20ms) 282.33ms (  1.19ms)       237
#     nlp_grad  |   4.33ms (  4.33ms)   4.31ms (  4.31ms)         1
#   nlp_grad_f  | 107.39ms (553.57us) 107.22ms (552.67us)       194
#   nlp_hess_l  |   3.60 s ( 17.21ms)   3.58 s ( 17.15ms)       209
#    nlp_jac_g  |   1.85 s (  8.69ms)   1.85 s (  8.66ms)       213
#        total  |   8.59 s (  8.59 s)   8.56 s (  8.56 s)         1
# 7.520159619051516e-07
# 2 -9444.374494950918
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 446.10ms (227.60us) 445.53ms (227.31us)      1960
#        nlp_g  |   2.33 s (  1.19ms)   2.32 s (  1.18ms)      1960
#     nlp_grad  |   4.42ms (  4.42ms)   4.40ms (  4.40ms)         1
#   nlp_grad_f  | 805.33ms (558.48us) 804.12ms (557.64us)      1442
#   nlp_hess_l  |  26.78 s ( 17.37ms)  26.69 s ( 17.31ms)      1542
#    nlp_jac_g  |  13.67 s (  8.78ms)  13.62 s (  8.75ms)      1556
#        total  |  68.76 s ( 68.76 s)  68.52 s ( 68.52 s)         1
# 7.254627572297498e-07
# 1 -7457.708896025666
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  23.75ms (146.60us)  23.61ms (145.75us)       162
#        nlp_g  | 191.90ms (  1.18ms) 191.42ms (  1.18ms)       162
#     nlp_grad  |   4.17ms (  4.17ms)   4.15ms (  4.15ms)         1
#   nlp_grad_f  |  44.38ms (293.88us)  44.35ms (293.72us)       151
#   nlp_hess_l  |   2.27 s ( 14.62ms)   2.26 s ( 14.57ms)       155
#    nlp_jac_g  |   1.37 s (  8.64ms)   1.37 s (  8.61ms)       159
#        total  |   5.52 s (  5.52 s)   5.50 s (  5.50 s)         1
# A -10574.165238413243
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  31.81ms (274.21us)  31.80ms (274.12us)       116
#        nlp_g  | 146.76ms (  1.27ms) 146.33ms (  1.26ms)       116
#     nlp_grad  |   4.51ms (  4.51ms)   4.49ms (  4.49ms)         1
#   nlp_grad_f  |  56.95ms (587.11us)  56.83ms (585.86us)        97
#   nlp_hess_l  |   1.93 s ( 17.70ms)   1.92 s ( 17.64ms)       109
#    nlp_jac_g  |   1.01 s (  8.92ms)   1.00 s (  8.89ms)       113
#        total  |   4.46 s (  4.46 s)   4.45 s (  4.45 s)         1
# 5.6269792900065e-08
# 2 -8077.941343539725
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 193.30ms (298.77us) 193.00ms (298.30us)       647
#        nlp_g  | 824.20ms (  1.27ms) 821.57ms (  1.27ms)       647
#     nlp_grad  |   4.40ms (  4.40ms)   4.38ms (  4.38ms)         1
#   nlp_grad_f  | 349.92ms (619.32us) 349.20ms (618.06us)       565
#   nlp_hess_l  |  11.50 s ( 17.95ms)  11.46 s ( 17.88ms)       641
#    nlp_jac_g  |   5.81 s (  9.00ms)   5.79 s (  8.97ms)       645
#        total  |  29.45 s ( 29.45 s)  29.35 s ( 29.35 s)         1
# 1.6939813847010883
# 1 -5660.963466721785
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  24.49ms (164.33us)  24.44ms (164.02us)       149
#        nlp_g  | 180.88ms (  1.21ms) 180.24ms (  1.21ms)       149
#     nlp_grad  |   4.50ms (  4.50ms)   4.50ms (  4.50ms)         1
#   nlp_grad_f  |  42.74ms (303.10us)  42.70ms (302.86us)       141
#   nlp_hess_l  |   2.12 s ( 14.90ms)   2.11 s ( 14.84ms)       142
#    nlp_jac_g  |   1.28 s (  8.77ms)   1.28 s (  8.74ms)       146
#        total  |   5.16 s (  5.16 s)   5.15 s (  5.15 s)         1
# A -9167.585025120266
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  55.30ms (298.92us)  55.24ms (298.58us)       185
#        nlp_g  | 234.77ms (  1.27ms) 234.24ms (  1.27ms)       185
#     nlp_grad  |   4.42ms (  4.42ms)   4.40ms (  4.40ms)         1
#   nlp_grad_f  |  58.89ms (588.94us)  58.82ms (588.19us)       100
#   nlp_hess_l  |   3.16 s ( 17.74ms)   3.15 s ( 17.67ms)       178
#    nlp_jac_g  |   1.62 s (  8.90ms)   1.61 s (  8.87ms)       182
#        total  |   7.24 s (  7.24 s)   7.21 s (  7.21 s)         1
# 4.9575485057681976e-08
# 2 -7014.8363243859785
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  29.27ms (292.73us)  29.22ms (292.18us)       100
#        nlp_g  | 122.55ms (  1.23ms) 122.19ms (  1.22ms)       100
#     nlp_grad  |   4.55ms (  4.55ms)   4.53ms (  4.53ms)         1
#   nlp_grad_f  |  48.05ms (600.69us)  48.01ms (600.08us)        80
#   nlp_hess_l  |   1.61 s ( 17.53ms)   1.61 s ( 17.48ms)        92
#    nlp_jac_g  | 845.29ms (  8.81ms) 842.25ms (  8.77ms)        96
#        total  |   3.68 s (  3.68 s)   3.67 s (  3.67 s)         1
# 2.135770867141848e-10
# 1 -10309.174866602567
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  84.23ms (161.37us)  84.04ms (160.99us)       522
#        nlp_g  | 625.11ms (  1.20ms) 623.40ms (  1.19ms)       522
#     nlp_grad  |   4.45ms (  4.45ms)   4.44ms (  4.44ms)         1
#   nlp_grad_f  | 158.24ms (303.13us) 158.15ms (302.97us)       522
#   nlp_hess_l  |   7.67 s ( 14.75ms)   7.64 s ( 14.70ms)       520
#    nlp_jac_g  |   4.54 s (  8.70ms)   4.52 s (  8.67ms)       522
#        total  |  18.54 s ( 18.54 s)  18.47 s ( 18.47 s)         1
# A -12732.711364565008
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 535.04ms (295.11us) 534.56ms (294.85us)      1813
#        nlp_g  |   2.23 s (  1.23ms)   2.23 s (  1.23ms)      1813
#     nlp_grad  |   4.32ms (  4.32ms)   4.30ms (  4.30ms)         1
#   nlp_grad_f  | 985.55ms (602.42us) 983.82ms (601.36us)      1636
#   nlp_hess_l  |  30.65 s ( 17.20ms)  30.55 s ( 17.14ms)      1782
#    nlp_jac_g  |  15.59 s (  8.72ms)  15.54 s (  8.69ms)      1788
#        total  |  72.71 s ( 72.71 s)  72.45 s ( 72.45 s)         1
# 3.1235625047624545e-08
# 2 -9752.69820606324
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 381.91ms (269.71us) 381.99ms (269.77us)      1416
#        nlp_g  |   1.62 s (  1.14ms)   1.61 s (  1.14ms)      1416
#     nlp_grad  |   4.41ms (  4.41ms)   4.39ms (  4.39ms)         1
#   nlp_grad_f  | 530.22ms (597.09us) 529.16ms (595.90us)       888
#   nlp_hess_l  |  18.62 s ( 16.93ms)  18.55 s ( 16.87ms)      1100
#    nlp_jac_g  |   9.53 s (  8.54ms)   9.50 s (  8.51ms)      1116
#        total  |  45.08 s ( 45.08 s)  44.92 s ( 44.92 s)         1
# 1.7925996600852963
# 1 -7913.935561740432
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  61.26ms (144.15us)  61.21ms (144.03us)       425
#        nlp_g  | 478.93ms (  1.13ms) 477.41ms (  1.12ms)       425
#     nlp_grad  |   4.26ms (  4.26ms)   4.24ms (  4.24ms)         1
#   nlp_grad_f  | 125.49ms (296.67us) 125.39ms (296.42us)       423
#   nlp_hess_l  |   5.92 s ( 14.07ms)   5.90 s ( 14.02ms)       421
#    nlp_jac_g  |   3.52 s (  8.32ms)   3.51 s (  8.29ms)       423
#        total  |  14.85 s ( 14.85 s)  14.80 s ( 14.80 s)         1
# A -10095.63988875112
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 124.10ms (283.34us) 124.05ms (283.22us)       438
#        nlp_g  | 533.13ms (  1.22ms) 531.37ms (  1.21ms)       438
#     nlp_grad  |   4.58ms (  4.58ms)   4.56ms (  4.56ms)         1
#   nlp_grad_f  | 250.30ms (594.54us) 249.88ms (593.54us)       421
#   nlp_hess_l  |   7.31 s ( 16.92ms)   7.28 s ( 16.86ms)       432
#    nlp_jac_g  |   3.76 s (  8.62ms)   3.75 s (  8.60ms)       436
#        total  |  16.87 s ( 16.87 s)  16.81 s ( 16.81 s)         1
# 5.573427007709592
# 2 -6034.165281860915
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  37.54ms (288.76us)  37.59ms (289.18us)       130
#        nlp_g  | 151.84ms (  1.17ms) 151.26ms (  1.16ms)       130
#     nlp_grad  |   4.33ms (  4.33ms)   4.31ms (  4.31ms)         1
#   nlp_grad_f  |  63.48ms (593.23us)  63.41ms (592.63us)       107
#   nlp_hess_l  |   1.99 s ( 16.85ms)   1.98 s ( 16.79ms)       118
#    nlp_jac_g  |   1.04 s (  8.52ms)   1.04 s (  8.49ms)       122
#        total  |   4.56 s (  4.56 s)   4.55 s (  4.55 s)         1
# 1.4561387910654929e-09
# 1 -10281.293932715862
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 191.75ms (146.93us) 191.74ms (146.92us)      1305
#        nlp_g  |   1.45 s (  1.11ms)   1.45 s (  1.11ms)      1305
#     nlp_grad  |   4.09ms (  4.09ms)   4.08ms (  4.08ms)         1
#   nlp_grad_f  | 345.17ms (292.27us) 344.76ms (291.92us)      1181
#   nlp_hess_l  |  17.96 s ( 13.95ms)  17.90 s ( 13.90ms)      1288
#    nlp_jac_g  |  10.69 s (  8.26ms)  10.66 s (  8.23ms)      1294
#        total  |  49.92 s ( 49.92 s)  49.75 s ( 49.75 s)         1
# A -13063.358338044905
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 148.42ms (296.24us) 148.37ms (296.15us)       501
#        nlp_g  | 595.88ms (  1.19ms) 594.01ms (  1.19ms)       501
#     nlp_grad  |   4.55ms (  4.55ms)   4.53ms (  4.53ms)         1
#   nlp_grad_f  | 160.87ms (595.81us) 160.53ms (594.57us)       270
#   nlp_hess_l  |   7.82 s ( 16.72ms)   7.80 s ( 16.66ms)       468
#    nlp_jac_g  |   4.06 s (  8.54ms)   4.05 s (  8.51ms)       476
#        total  |  18.67 s ( 18.67 s)  18.60 s ( 18.60 s)         1
# 0.02221682603678
# 2 -9513.08548450786
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 343.07ms (354.05us) 342.78ms (353.74us)       969
#        nlp_g  |   1.19 s (  1.23ms)   1.19 s (  1.23ms)       969
#     nlp_grad  |   4.53ms (  4.53ms)   4.51ms (  4.51ms)         1
#   nlp_grad_f  | 448.76ms (653.22us) 447.96ms (652.05us)       687
#   nlp_hess_l  |  16.55 s ( 17.53ms)  16.49 s ( 17.47ms)       944
#    nlp_jac_g  |   8.38 s (  8.78ms)   8.35 s (  8.75ms)       954
#        total  |  38.94 s ( 38.94 s)  38.80 s ( 38.80 s)         1
# 1.5058718605482129e-24
# 1 -10311.841371532631
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  37.80ms (162.23us)  37.65ms (161.58us)       233
#        nlp_g  | 266.30ms (  1.14ms) 265.59ms (  1.14ms)       233
#     nlp_grad  |   4.16ms (  4.16ms)   4.14ms (  4.14ms)         1
#   nlp_grad_f  |  66.64ms (305.71us)  66.70ms (305.96us)       218
#   nlp_hess_l  |   3.21 s ( 14.28ms)   3.20 s ( 14.23ms)       225
#    nlp_jac_g  |   1.93 s (  8.42ms)   1.92 s (  8.39ms)       229
#        total  |   8.47 s (  8.47 s)   8.43 s (  8.43 s)         1
# A -11864.541816537467
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 540.87ms (345.39us) 540.62ms (345.22us)      1566
#        nlp_g  |   2.03 s (  1.30ms)   2.02 s (  1.29ms)      1566
#     nlp_grad  |   4.70ms (  4.70ms)   4.69ms (  4.69ms)         1
#   nlp_grad_f  | 914.33ms (652.63us) 912.45ms (651.28us)      1401
#   nlp_hess_l  |  27.37 s ( 17.54ms)  27.27 s ( 17.47ms)      1561
#    nlp_jac_g  |  13.88 s (  8.87ms)  13.83 s (  8.84ms)      1565
#        total  |  63.82 s ( 63.82 s)  63.58 s ( 63.58 s)         1
# 7.01753400207042e-08
# 2 -9185.142786224773
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 649.05ms (374.31us) 648.67ms (374.09us)      1734
#        nlp_g  |   2.16 s (  1.25ms)   2.16 s (  1.24ms)      1734
#     nlp_grad  |   4.67ms (  4.67ms)   4.65ms (  4.65ms)         1
#   nlp_grad_f  |   1.04 s (674.80us)   1.04 s (673.40us)      1537
#   nlp_hess_l  |  29.00 s ( 17.63ms)  28.90 s ( 17.57ms)      1645
#    nlp_jac_g  |  14.64 s (  8.84ms)  14.59 s (  8.81ms)      1655
#        total  |  78.28 s ( 78.28 s)  78.00 s ( 78.00 s)         1
# 7.184199329239023
# 1 -7160.510691795359
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  55.11ms (193.38us)  55.07ms (193.24us)       285
#        nlp_g  | 344.90ms (  1.21ms) 344.02ms (  1.21ms)       285
#     nlp_grad  |   4.38ms (  4.38ms)   4.36ms (  4.36ms)         1
#   nlp_grad_f  |  90.45ms (336.24us)  90.38ms (336.00us)       269
#   nlp_hess_l  |   4.12 s ( 14.94ms)   4.11 s ( 14.90ms)       276
#    nlp_jac_g  |   2.47 s (  8.83ms)   2.46 s (  8.80ms)       280
#        total  |  10.18 s ( 10.18 s)  10.15 s ( 10.15 s)         1
# A -9916.073866107603
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.79 s (211.34us)   1.79 s (211.63us)      8469
#        nlp_g  |   8.87 s (  1.05ms)   8.84 s (  1.04ms)      8469
#     nlp_grad  |   4.49ms (  4.49ms)   4.47ms (  4.47ms)         1
#   nlp_grad_f  | 999.10ms (607.72us) 996.90ms (606.39us)      1644
#   nlp_hess_l  |  29.16 s ( 17.53ms)  29.06 s ( 17.47ms)      1663
#    nlp_jac_g  |  14.72 s (  8.78ms)  14.67 s (  8.75ms)      1677
#        total  |  79.75 s ( 79.75 s)  79.47 s ( 79.47 s)         1
# 30.85172037335795
# 2 -5580.457168671453
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  29.97ms (329.31us)  29.94ms (329.04us)        91
#        nlp_g  | 107.83ms (  1.18ms) 107.49ms (  1.18ms)        91
#     nlp_grad  |   4.31ms (  4.31ms)   4.29ms (  4.29ms)         1
#   nlp_grad_f  |  47.62ms (643.58us)  47.55ms (642.54us)        74
#   nlp_hess_l  |   1.45 s ( 17.05ms)   1.44 s ( 16.99ms)        85
#    nlp_jac_g  | 762.05ms (  8.56ms) 759.48ms (  8.53ms)        89
#        total  |   3.34 s (  3.34 s)   3.32 s (  3.32 s)         1
# 9.28664911096711e-27
# 1 -10311.841371544087
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 136.52ms (171.94us) 136.58ms (172.02us)       794
#        nlp_g  | 917.67ms (  1.16ms) 915.10ms (  1.15ms)       794
#     nlp_grad  |   4.21ms (  4.21ms)   4.19ms (  4.19ms)         1
#   nlp_grad_f  | 219.72ms (322.65us) 219.78ms (322.74us)       681
#   nlp_hess_l  |  11.31 s ( 14.45ms)  11.27 s ( 14.40ms)       783
#    nlp_jac_g  |   6.69 s (  8.48ms)   6.67 s (  8.45ms)       789
#        total  |  28.30 s ( 28.30 s)  28.19 s ( 28.19 s)         1
# A -13986.46662085065
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 754.90ms (307.12us) 754.27ms (306.86us)      2458
#        nlp_g  |   3.01 s (  1.22ms)   3.00 s (  1.22ms)      2458
#     nlp_grad  |   4.60ms (  4.60ms)   4.58ms (  4.58ms)         1
#   nlp_grad_f  |   1.13 s (639.39us)   1.13 s (638.54us)      1775
#   nlp_hess_l  |  33.37 s ( 17.32ms)  33.25 s ( 17.26ms)      1927
#    nlp_jac_g  |  17.03 s (  8.76ms)  16.97 s (  8.73ms)      1943
#        total  |  88.48 s ( 88.48 s)  88.16 s ( 88.16 s)         1
# 3.194434033220953e-08
# 2 -9934.367520656117
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 657.16ms (349.18us) 656.81ms (348.99us)      1882
#        nlp_g  |   2.25 s (  1.20ms)   2.25 s (  1.19ms)      1882
#     nlp_grad  |   4.62ms (  4.62ms)   4.60ms (  4.60ms)         1
#   nlp_grad_f  |   1.02 s (654.34us)   1.02 s (653.08us)      1566
#   nlp_hess_l  |  30.90 s ( 17.03ms)  30.79 s ( 16.97ms)      1814
#    nlp_jac_g  |  15.68 s (  8.60ms)  15.63 s (  8.57ms)      1824
#        total  |  81.02 s ( 81.02 s)  80.73 s ( 80.73 s)         1
# 3.861836719099398e-18
# 1 -10311.841371984454
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  52.45ms (165.46us)  52.55ms (165.76us)       317
#        nlp_g  | 364.18ms (  1.15ms) 362.94ms (  1.14ms)       317
#     nlp_grad  |   4.02ms (  4.02ms)   4.02ms (  4.02ms)         1
#   nlp_grad_f  |  100.00ms (314.46us)  99.97ms (314.37us)       318
#   nlp_hess_l  |   4.54 s ( 14.37ms)   4.52 s ( 14.32ms)       316
#    nlp_jac_g  |   2.70 s (  8.49ms)   2.69 s (  8.47ms)       318
#        total  |  10.88 s ( 10.88 s)  10.85 s ( 10.85 s)         1
# A -11450.971708575305
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 117.40ms (369.17us) 117.47ms (369.42us)       318
#        nlp_g  | 416.19ms (  1.31ms) 415.55ms (  1.31ms)       318
#     nlp_grad  |   4.92ms (  4.92ms)   4.91ms (  4.91ms)         1
#   nlp_grad_f  | 131.05ms (668.60us) 131.03ms (668.53us)       196
#   nlp_hess_l  |   5.42 s ( 17.47ms)   5.41 s ( 17.44ms)       310
#    nlp_jac_g  |   2.78 s (  8.86ms)   2.78 s (  8.84ms)       314
#        total  |  12.27 s ( 12.27 s)  12.24 s ( 12.24 s)         1
# 8.815272871954881e-07
# 2 -9447.455087059801
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  94.60ms (414.93us)  94.47ms (414.33us)       228
#        nlp_g  | 284.54ms (  1.25ms) 283.70ms (  1.24ms)       228
#     nlp_grad  |   4.53ms (  4.53ms)   4.52ms (  4.52ms)         1
#   nlp_grad_f  |  50.84ms (668.89us)  50.82ms (668.68us)        76
#   nlp_hess_l  |   3.88 s ( 17.49ms)   3.87 s ( 17.43ms)       222
#    nlp_jac_g  |   1.98 s (  8.76ms)   1.97 s (  8.74ms)       226
#        total  |   9.74 s (  9.74 s)   9.71 s (  9.71 s)         1
# 9.67771308460248e-17
# 1 -10311.841371475748

# %% [markdown]
# ## Why is agent one doing weird things?

# %%
subdir_name = "20200220-163834_ibr_ego_finalcosts"
folder = "results/" + subdir_name + "/"

br2 = mpc.IterativeBestResponseMPC(x1_MPC, x2_MPC, amb_MPC )
br2.generate_optimization(N, min_dist, fd, T, x0_2, x0, x0_amb, 2, slack=True)

for ibr_sub_it in range(27, 37):
    if (ibr_sub_it % 3) == 0:
        response_car = "1"
    elif (ibr_sub_it % 3) == 1:
        response_car = "a"
    else:
        response_car = "2"
    ibr_prefix =  '%02d'%ibr_sub_it + "_" + response_car
    x1, u1, x1_des, x2, u2, x2_des, xamb, uamb, xamb_des = br2.load_state(folder + ibr_prefix)
    CIRCLES = False
    cplot.plot_cars_multiproc(x1, x2, xamb, folder, x1_des, x2_des, xamb_des, CIRCLES, min_dist)
    if CIRCLES:
        vid_fname = folder + subdir_name + 'circle_' + ibr_prefix3 + '.mp4'
    else:
        vid_fname = folder + subdir_name + 'car_' + ibr_prefix +'.mp4'    
    if os.path.exists(vid_fname):
        os.remove(vid_fname)
    cmd = 'ffmpeg -r 16 -f image2 -i {}imgs/%03d.png -vcodec libx264 -crf 25  -pix_fmt yuv420p {}'.format(folder, vid_fname)
    os.system(cmd)
    print('Saving video to: {}'.format(vid_fname))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-abad2c331d1f> in <module>
#      15     x1, u1, x1_des, x2, u2, x2_des, xamb, uamb, xamb_des = br2.load_state(folder + ibr_prefix)
#      16     CIRCLES = False
# ---> 17     cplot.plot_cars_multiproc(x1, x2, xamb, folder, x1_des, x2_des, xamb_des, CIRCLES, min_dist)
#      18     if CIRCLES:
#      19         vid_fname = folder + subdir_name + 'circle_' + ibr_prefix3 + '.mp4'
#
# ~/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/car_plotting.py in plot_cars_multiproc(x1_plot, x2_plot, xamb_plot, folder, x1_desired, x2_desired, xamb_desired, CIRCLES, min_dist, SLIDING_WINDOW)
#     186                                     x1_desired=x1_desired, x2_desired=x2_desired, xamb_desired=xamb_desired, folder=folder)
#     187
# --> 188     pool.map(plot_partial, range(N)) #will apply k=1...N to plot_partial
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
# Process ForkPoolWorker-531:
# Traceback (most recent call last):
# Process ForkPoolWorker-534:
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-529:
# Process ForkPoolWorker-535:
# Process ForkPoolWorker-533:
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-536:
#   File "/home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/car_plotting.py", line 155, in plot_three_cars
#     ax = get_frame(xamb_plot[:,k], ax, "Amb", min_dist,CIRCLES)
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/car_plotting.py", line 50, in get_frame
#     rotated_img = ndimage.rotate(arr_img, degree)
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/car_plotting.py", line 155, in plot_three_cars
#     ax = get_frame(xamb_plot[:,k], ax, "Amb", min_dist,CIRCLES)
#   File "/home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/car_plotting.py", line 155, in plot_three_cars
#     ax = get_frame(xamb_plot[:,k], ax, "Amb", min_dist,CIRCLES)
#   File "/home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/car_plotting.py", line 50, in get_frame
#     rotated_img = ndimage.rotate(arr_img, degree)
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/car_plotting.py", line 50, in get_frame
#     rotated_img = ndimage.rotate(arr_img, degree)
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/nbuckman/.local/lib/python3.7/site-packages/scipy/ndimage/interpolation.py", line 744, in rotate
#     oa, order, mode, cval, prefilter)
#   File "/home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/car_plotting.py", line 155, in plot_three_cars
#     ax = get_frame(xamb_plot[:,k], ax, "Amb", min_dist,CIRCLES)
#   File "/home/nbuckman/.local/lib/python3.7/site-packages/scipy/ndimage/interpolation.py", line 486, in affine_transform
#     output, order, mode, cval, None, None)
#   File "/home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/car_plotting.py", line 50, in get_frame
#     rotated_img = ndimage.rotate(arr_img, degree)
# KeyboardInterrupt
#   File "/home/nbuckman/.local/lib/python3.7/site-packages/scipy/ndimage/interpolation.py", line 744, in rotate
#     oa, order, mode, cval, prefilter)
#   File "/home/nbuckman/.local/lib/python3.7/site-packages/scipy/ndimage/interpolation.py", line 486, in affine_transform
#     output, order, mode, cval, None, None)
#   File "/home/nbuckman/.local/lib/python3.7/site-packages/scipy/ndimage/interpolation.py", line 744, in rotate
#     oa, order, mode, cval, prefilter)
#   File "/home/nbuckman/.local/lib/python3.7/site-packages/scipy/ndimage/interpolation.py", line 486, in affine_transform
#     output, order, mode, cval, None, None)
# KeyboardInterrupt
#   File "/home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/car_plotting.py", line 155, in plot_three_cars
#     ax = get_frame(xamb_plot[:,k], ax, "Amb", min_dist,CIRCLES)
#   File "/home/nbuckman/.local/lib/python3.7/site-packages/scipy/ndimage/interpolation.py", line 744, in rotate
#     oa, order, mode, cval, prefilter)
#   File "/home/nbuckman/.local/lib/python3.7/site-packages/scipy/ndimage/interpolation.py", line 486, in affine_transform
#     output, order, mode, cval, None, None)
# KeyboardInterrupt
#   File "/home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/car_plotting.py", line 50, in get_frame
#     rotated_img = ndimage.rotate(arr_img, degree)
# KeyboardInterrupt
#   File "/home/nbuckman/.local/lib/python3.7/site-packages/scipy/ndimage/interpolation.py", line 744, in rotate
#     oa, order, mode, cval, prefilter)
#   File "/home/nbuckman/.local/lib/python3.7/site-packages/scipy/ndimage/interpolation.py", line 486, in affine_transform
#     output, order, mode, cval, None, None)
# KeyboardInterrupt
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Process ForkPoolWorker-530:
# Process ForkPoolWorker-532:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/car_plotting.py", line 155, in plot_three_cars
#     ax = get_frame(xamb_plot[:,k], ax, "Amb", min_dist,CIRCLES)
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/car_plotting.py", line 50, in get_frame
#     rotated_img = ndimage.rotate(arr_img, degree)
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/nbuckman/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/car_plotting.py", line 155, in plot_three_cars
#     ax = get_frame(xamb_plot[:,k], ax, "Amb", min_dist,CIRCLES)
#   File "/home/nbuckman/.local/lib/python3.7/site-packages/scipy/ndimage/interpolation.py", line 744, in rotate
#     oa, order, mode, cval, prefilter)
#   File "/home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/car_plotting.py", line 155, in plot_three_cars
#     ax = get_frame(xamb_plot[:,k], ax, "Amb", min_dist,CIRCLES)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   File "/home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/car_plotting.py", line 50, in get_frame
#     rotated_img = ndimage.rotate(arr_img, degree)
#   File "/home/nbuckman/.local/lib/python3.7/site-packages/scipy/ndimage/interpolation.py", line 444, in affine_transform
#     filtered = spline_filter(input, order, output=numpy.float64)
#   File "/home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/car_plotting.py", line 50, in get_frame
#     rotated_img = ndimage.rotate(arr_img, degree)
#   File "/home/nbuckman/.local/lib/python3.7/site-packages/scipy/ndimage/interpolation.py", line 744, in rotate
#     oa, order, mode, cval, prefilter)
#   File "/home/nbuckman/.local/lib/python3.7/site-packages/scipy/ndimage/interpolation.py", line 744, in rotate
#     oa, order, mode, cval, prefilter)
#   File "/home/nbuckman/.local/lib/python3.7/site-packages/scipy/ndimage/interpolation.py", line 444, in affine_transform
#     filtered = spline_filter(input, order, output=numpy.float64)
#   File "/home/nbuckman/.local/lib/python3.7/site-packages/scipy/ndimage/interpolation.py", line 444, in affine_transform
#     filtered = spline_filter(input, order, output=numpy.float64)
#   File "/home/nbuckman/.local/lib/python3.7/site-packages/scipy/ndimage/interpolation.py", line 135, in spline_filter
#     spline_filter1d(input, order, axis, output=output, mode=mode)
#   File "/home/nbuckman/.local/lib/python3.7/site-packages/scipy/ndimage/interpolation.py", line 104, in spline_filter1d
#     _nd_image.spline_filter1d(input, order, axis, output, mode)
#   File "/home/nbuckman/.local/lib/python3.7/site-packages/scipy/ndimage/interpolation.py", line 135, in spline_filter
#     spline_filter1d(input, order, axis, output=output, mode=mode)
#   File "/home/nbuckman/.local/lib/python3.7/site-packages/scipy/ndimage/interpolation.py", line 135, in spline_filter
#     spline_filter1d(input, order, axis, output=output, mode=mode)
#   File "/home/nbuckman/.local/lib/python3.7/site-packages/scipy/ndimage/interpolation.py", line 104, in spline_filter1d
#     _nd_image.spline_filter1d(input, order, axis, output, mode)
# KeyboardInterrupt
#   File "/home/nbuckman/.local/lib/python3.7/site-packages/scipy/ndimage/interpolation.py", line 104, in spline_filter1d
#     _nd_image.spline_filter1d(input, order, axis, output, mode)
# KeyboardInterrupt
# KeyboardInterrupt

# %% [markdown]
# ## Studying Agent's Iteration

# %%
br2 = mpc.IterativeBestResponseMPC(x1_MPC, x2_MPC, amb_MPC )
br2.generate_optimization(N, min_dist, fd, T, x0_2, x0, x0_amb, 2, slack=True)
fig, ax = plt.subplots(5,1)
ax_t = ax[0]
ax_u0 = ax[1]
ax_u1 = ax[2]
ax_usum = ax[3]
ax_xmax = ax[4]
n_total_round = 12

all_amb = np.zeros((6,101, int(n_total_round)))
subdir_name = "20200220-163834_ibr_ego_finalcosts"
folder = "results/" + subdir_name + "/"

initial = True
for ibr_sub_it in range(1, 3*n_total_round + 1):
    if (ibr_sub_it % 3) == 0:
        response_car = "1"
    elif (ibr_sub_it % 3) == 1:
        response_car = "a"
    else:
        response_car = "2"
        
    if response_car == "a":
        ibr_prefix =  '%02d'%ibr_sub_it + "_" + response_car
            
        x1, u1, x1_des, x2, u2, x2_des, xamb, uamb, xamb_des = br2.load_state(folder + ibr_prefix)
        if initial:
            prev_u = uamb
            initial = False
        
        change_in_u = uamb - prev_u
        mag_change_in_u = (change_in_u**2).sum()
        
        ax_t.plot(xamb[0,:],xamb[1,:],'.')
        ax_u0.plot(uamb[0,:],'.')
        ax_u1.plot(uamb[1,:],'.')
        ax_usum.plot(ibr_sub_it, mag_change_in_u,'o')
        ax_xmax.plot(ibr_sub_it, xamb[0,-1],'p')
        prev_u = uamb
        
        all_amb[:,:,int(ibr_sub_it/3)] = xamb
        

ax_t.set_ylabel('y [m]')
ax_t.set_xlabel('x [m]')

ax_u0.set_ylabel('u0')
ax_u0.set_xlabel('t [100ms]')

ax_u1.set_ylabel('u1')
ax_u1.set_xlabel('t [100ms]')

ax_usum.set_ylabel(r'$\Delta u^2$')
ax_usum.set_xlabel('ibr iteration')

ax_xmax.set_ylabel(r'$x_{\max}$')
ax_xmax.set_xlabel('ibr iteration')
ax_xmax.set_ylim([80,125])

plt.show()

# %%
max_x = np.max(all_amb[0,:,:],axis=0)
print("Ego: Final %.02f Mean %.02f Max %.02f, Min %.02f"%(max_x[-1], np.mean(max_x), np.max(max_x), np.min(max_x)))
print(max_x)
# Out:
# Ego: Final 107.32 Mean 105.36 Max 118.26, Min 91.10
# [ 91.1  118.26 107.04 103.33  99.07 107.09 107.11 109.21 107.83  99.98
#  107.03 107.32]
