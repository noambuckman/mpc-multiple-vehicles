# %%
# %load_ext autoreload
# %autoreload 2

import datetime
import os, sys
import numpy as np
import matplotlib.pyplot as plt

import casadi as cas
import pickle
import copy as cp

import argparse

PROJECT_PATH = '/home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/'
sys.path.append(PROJECT_PATH)

import src.MPC_Casadi as mpc
import src.TrafficWorld as tw
import src.IterativeBestResponseMPCMultiple as mibr
import src.car_plotting_multiple as cmplot

np.set_printoptions(precision=2)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# random_seed = args.random_seed[0]

svo_theta = np.pi/4.0

random_seed = 3
NEW = True
if NEW:
    optional_suffix = "ellipses"
    subdir_name = datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + optional_suffix
    folder = "results/" + subdir_name + "/"
    os.makedirs(folder)
    os.makedirs(folder+"imgs/")
    os.makedirs(folder+"data/")
    os.makedirs(folder+"vids/")
    os.makedirs(folder+"plots/")
else:
    subdir_name = "20200224-103456_real_dim_CA"
    folder = "results/" + subdir_name + "/"
print(folder)
if random_seed > 0:
    np.random.seed(random_seed)
# Out:
# results/20200311_162909ellipses/

# %%
T = 3
dt = 0.2
N = int(T/dt) #Number of control intervals
print(N)
world = tw.TrafficWorld(2, 0, 1000)
n_other = 1

all_other_x0 = []
all_other_u = []
all_other_MPC = []
next_x0 = 0
for i in range(n_other):
    x1_MPC = mpc.MPC(dt)
    x1_MPC.n_circles = 3
    x1_MPC.theta_iamb =  svo_theta
    x1_MPC.N = N
    
    
    

    x1_MPC.k_u_v = 0.01
    x1_MPC.k_u_delta = .00001
    x1_MPC.k_change_u_v = 0.01
    x1_MPC.k_change_u_delta = 0

    x1_MPC.k_s = 0
    x1_MPC.k_x = 0
    x1_MPC.k_x_dot = -1.0 / 100.0
    x1_MPC.k_lat = 0.001
    x1_MPC.k_lon = 0.0
#     x1_MPC.min_v = 0.8*initial_speed
#     x1_MPC.max_v = 35 * 0.447 # m/s


    x1_MPC.k_phi_error = 0.001
    x1_MPC.k_phi_dot = 0.0
    
    
    
    
#     x1_MPC.k_final = 0.0
#     x1_MPC.k_s = 0
#     x1_MPC.k_x = 0
#     x1_MPC.k_x_dot = -1.0 / 100.0    

#     # x1_MPC.k_u_v = 1.0
#     # x1_MPC.k_u_delta = 1.00
#     # x1_MPC.k_lat = .25
#     # x1_MPC.k_change_u_v = .50
#     # x1_MPC.k_change_u_delta = .50    

#     x1_MPC.k_u_v = .10
#     x1_MPC.k_u_delta = .01
#     x1_MPC.k_lat = 5.0
#     x1_MPC.k_lon = 0.01
#     x1_MPC.k_phi_error = 0.05 
#     x1_MPC.k_change_u_v = .01
#     x1_MPC.k_change_u_delta = .01        

#     NO_GRASS = False
#     x1_MPC.min_y = world.y_min        
#     x1_MPC.max_y = world.y_max
#     if NO_GRASS:
#         x1_MPC.min_y += world.grass_width
#         x1_MPC.max_y -= world.grass_width
    # x1_MPC.k_phi_error = 25

    if i%2 == 0:
        lane_number = 0
        next_x0 += x1_MPC.L + 2*x1_MPC.min_dist
    else:
        lane_number = 1

    initial_speed = 20 * 0.447 # m/s
    initial_speed = x1_MPC.max_v
    initial_speed = 0.75*x1_MPC.max_v

    # large_world = tw.TrafficWorld(2, 0, 1000, 5.0)
    traffic_world = tw.TrafficWorld(2, 0, 1000)


    x1_MPC.fd = x1_MPC.gen_f_desired_lane(traffic_world, lane_number, True)

    x0 = np.array([next_x0, traffic_world.get_lane_centerline_y(lane_number), 0, 0, initial_speed, 0]).T
    u1 = np.zeros((2,N))
    # u1[0,:] = np.clip(np.pi/180 *np.random.normal(size=(1,N)), -2 * np.pi/180, 2 * np.pi/180)
    SAME_SIDE = False
    if lane_number == 1 or SAME_SIDE:
        u1[0,0] = 2 * np.pi/180
    else:
        u1[0,0] = -2 * np.pi/180
    u1[0,0] = 0 ###
    all_other_MPC += [x1_MPC]
    all_other_x0 += [x0]
    all_other_u += [u1]    
pickle.dump(x1_MPC, open(folder + "data/"+"mpc%d"%i + ".p",'wb'))


amb_MPC = cp.deepcopy(x1_MPC)

amb_MPC.theta_iamb = 0.0

amb_MPC.k_u_v = 0.01
amb_MPC.k_u_delta = .00001
amb_MPC.k_change_u_v = 0.01
amb_MPC.k_change_u_delta = 0

amb_MPC.k_s = 0
amb_MPC.k_x = 0
amb_MPC.k_x_dot = -1.0 / 100.0
amb_MPC.k_lat = 0.001
amb_MPC.k_lon = 0.0
amb_MPC.min_v = 0.8*initial_speed
amb_MPC.max_v = 35 * 0.447 # m/s


amb_MPC.k_phi_error = 0.001
amb_MPC.k_phi_dot = 0.0

NO_GRASS = False
amb_MPC.min_y = world.y_min        
amb_MPC.max_y = world.y_max
if NO_GRASS:
    amb_MPC.min_y += world.grass_width
    amb_MPC.max_y -= world.grass_width
# x1_MPC.k_phi_error = 25
amb_MPC.fd = amb_MPC.gen_f_desired_lane(world, 0, True)
pickle.dump(amb_MPC, open(folder + "data/"+"mpcamb" + ".p",'wb'))
x0_amb = np.array([0, 0, 0, 0, initial_speed , 0]).T
uamb = np.zeros((2,N))
# uamb[0,:] = np.clip(np.pi/180 * np.random.normal(size=(1,N)), -2 * np.pi/180, 2 * np.pi/180)
uamb[0,0] = np.pi/180 * 5
# uamb[0,0] = 2 * np.pi/180
# amb_MPC.radius = 0.1

n_rounds_mpc = 20 # seconds
number_ctrl_pts_executed = 5  #dt = 0.2
actual_xamb = np.zeros((6, n_rounds_mpc*number_ctrl_pts_executed + 1))
actual_uamb = np.zeros((2, n_rounds_mpc*number_ctrl_pts_executed))
actual_xothers = [np.zeros((6, n_rounds_mpc*number_ctrl_pts_executed + 1)) for i in range(n_other)]
actual_uothers = [np.zeros((2, n_rounds_mpc*number_ctrl_pts_executed)) for i in range(n_other)]

# actual_xamb[:,0] = x0_amb

actual_all_other_x0 = [np.zeros((6, 2*N)) for i in range(n_other)]
XAMB_ONLY = True
WARM = True
UWARM = True

xamb = None
ibr_sub_it = 1

uamb_warm = np.zeros((2,N))
uamb_warm[0,0] = np.pi/4
uamb_warm[0,1:5] = 0
uamb_warm[0,5:10] = -np.pi/4
xamb_warm = np.zeros((6,N+1))
xamb_warm[1,:] = traffic_world.get_lane_centerline_y(1) * 0.5
xamb_warm[0,:] = amb_MPC.dt * x0_amb[4] * np.arange(N+1)

all_other_xwarm = [i for i in range(n_other)]
for i_mpc in range(n_rounds_mpc):
    runtimeerrors = 0
#     min_slack = 99999.0
    min_slack = np.infty
    if i_mpc > 0:
        ### THIS SHOULD BE CHANGED FOR GLOBAL TRUTH?
        all_other_u = [np.zeros((2,N)) for i in range(n_other)] ## <--We are setting the other vehicle inputs
        
        
        x0_amb = xamb[:,number_ctrl_pts_executed] # NEW INITIAL STATE
        for i in range(len(all_other_x0)):
            all_other_x0[i] = xothers[i][:,number_ctrl_pts_executed]
        uamb_warm = np.concatenate((uamb[:, number_ctrl_pts_executed:], np.tile(uamb[:,-1:],(1, number_ctrl_pts_executed))),axis=1) ##
        xamb_warm = np.concatenate((xamb[:, number_ctrl_pts_executed:] , np.tile(xamb[:,-1:],(1, number_ctrl_pts_executed))),axis=1)  ## <--- Warmstart            
        for i in range(len(all_other_x0)):
            all_other_xwarm[i] = np.concatenate((xothers[i][:, number_ctrl_pts_executed:] , np.tile(xothers[i][:,-1:],(1, number_ctrl_pts_executed))),axis=1)  ## <--- Warmstart            
                    
    actual_t = i_mpc * number_ctrl_pts_executed
    print("x0amb", x0_amb)
    n_total_round = 5
    for n_round in range(n_total_round):   
        response_MPC = amb_MPC
        response_x0 = x0_amb

        nonresponse_MPC_list = all_other_MPC
        nonresponse_x0_list = all_other_x0
        nonresponse_u_list = all_other_u
        
        bri = mibr.IterativeBestResponseMPCMultiple(response_MPC, None, nonresponse_MPC_list )
        bri.k_slack = 1000.0
        bri.k_CA = 10.0
        bri.generate_optimization(N, T, response_x0, None, nonresponse_x0_list,  5, slack=True)
        for slack_var in bri.slack_vars_list: ## Added to constrain slacks
            bri.opti.subject_to(cas.vec(slack_var) < .1)
        INFEASIBLE = True
        if i_mpc >= 0:
            print(xamb_warm[0:2,:])
            bri.opti.set_initial(bri.x_opt, xamb_warm)
            bri.opti.set_initial(bri.u_opt, uamb_warm)
        
#         bri.opti.subject_to(bri.x_opt[1,:] > 0.0)
        bri.solve(None, nonresponse_u_list)
        x1, u1, x1_des, _, _, _, other_x, other_u, other_des = bri.get_solution()
        xothers = other_x # initialize the x values of the other vehicles
        uothers = other_u
        xothers_des = other_des
        print("i_mpc %d n_round %d i %02d Cost %.02f Slack %.02f "%(i_mpc, n_round, i, bri.solution.value(bri.total_svo_cost), bri.solution.value(bri.slack_cost)))
        print("J_i %.03f,  J_j %.03f, Slack %.03f, CA  %.03f"%(bri.solution.value(bri.response_svo_cost), bri.solution.value(bri.other_svo_cost), bri.solution.value(bri.k_slack*bri.slack_cost), bri.solution.value(bri.k_CA*bri.collision_cost)))
        print("Dir:", subdir_name)
        INFEASIBLE = False
        if bri.solution.value(bri.slack_cost) <= min_slack:
            uamb = u1
            xamb = x1
            xamb_des = x1_des
            # all_other_u[i] = u1
            file_name = folder + "data/"+'%03d'%ibr_sub_it
            mibr.save_state(file_name, x1, u1, x1_des, other_x, other_u, other_des)
            mibr.save_costs(file_name, bri)          
#         except RuntimeError:
#             print("Max Iterations or Infeasible")
#             INFEASIBLE = True
#             runtimeerrors += 1                
        ibr_sub_it +=1
        XAMB_ONLY = True
        if XAMB_ONLY:
            pass
        else:
            for i in range(len(all_other_MPC)):
                response_MPC = all_other_MPC[i]
                response_x0 = all_other_x0[i]

                nonresponse_MPC_list = all_other_MPC[:i] + all_other_MPC[i+1:]
                nonresponse_x0_list = all_other_x0[:i] + all_other_x0[i+1:]

                # all_other_u changes over time
                nonresponse_u_list = all_other_u[:i] + all_other_u[i+1:]

                bri = mibr.IterativeBestResponseMPCMultiple(response_MPC, amb_MPC, nonresponse_MPC_list )
                bri.k_slack = 1000.0
                bri.k_CA = 10.0
                bri.generate_optimization(N, T, response_x0, x0_amb, nonresponse_x0_list,  1, slack=True)
                WARM = True
                try:
                    if WARM:
                        bri.opti.set_initial(bri.x_opt, xothers[i])
                        bri.opti.set_initial(bri.u_opt, uothers[i])

                    bri.solve(uamb, nonresponse_u_list)
                    x1, u1, x1_des, xamb, uamb, xamb_des, other_x, other_u, other_des = bri.get_solution()
                    print("i_mpc %d n_round %d  i %02d Cost %.02f Slack %.02f "%(i_mpc, n_round, i, bri.solution.value(bri.total_svo_cost), bri.solution.value(bri.slack_cost)))
                    print("Dir:", subdir_name)

                    if bri.solution.value(bri.slack_cost) <= min_slack:
                        # Update the responder
                        all_other_u[i] = u1

                        #for saving
                        xothers = other_x[:i] + [x1] + other_x[i:]
                        uothers = other_u[:i] + [u1] + other_u[i:]
                        xothers_des = other_des[:i] + [x1_des] + other_des[i:]

                        file_name = folder + "data/"+'%03d'%ibr_sub_it
                        mibr.save_state(file_name, xamb, uamb, xamb_des, xothers, uothers, xothers_des)
                        mibr.save_costs(file_name, bri)
                    else: 
                        print("Slack too large")    
                except RuntimeError:
                    print("Max Iterations or Infeasible")
                    runtimeerrors += 1   
                ibr_sub_it+=1

    file_name = folder + "data/"+'r%02d%03d'%(i_mpc, n_round)
    if not INFEASIBLE:
        for cost in bri.car1_costs_list:
            print("%.04f"%bri.solution.value(cost))
        print(bri.solution.value(bri.k_CA * bri.collision_cost), bri.solution.value(bri.collision_cost))
        print(bri.solution.value(bri.k_slack * bri.slack_cost), bri.solution.value(bri.slack_cost))
        mibr.save_state(file_name, xamb, uamb, xamb_des, xothers, uothers, xothers_des)
        mibr.save_costs(file_name, bri)
        actual_t = i_mpc * number_ctrl_pts_executed
        actual_xamb[:,actual_t:actual_t+number_ctrl_pts_executed+1]  = xamb[:,:number_ctrl_pts_executed+1]
        print(i_mpc, xamb[0:2,:number_ctrl_pts_executed+1])

        actual_uamb[:,actual_t:actual_t+number_ctrl_pts_executed] = uamb[:,:number_ctrl_pts_executed]

        for i in range(len(xothers)):
            actual_xothers[i][:,actual_t:actual_t+number_ctrl_pts_executed+1] = xothers[i][:,:number_ctrl_pts_executed+1]
            actual_uothers[i][:,actual_t:actual_t+number_ctrl_pts_executed] = uothers[i][:,:number_ctrl_pts_executed]
#             all_other_u[i] = np.concatenate((uothers[i][:, number_ctrl_pts_executed:],uothers[i][:,:number_ctrl_pts_executed]),axis=1)
    else:
5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  260r 3.7392071e+03 8.62e-01 9.90e+02  -0.1 2.93e+01    -  2.16e-02 1.26e-02f  1
#  261r 3.7415462e+03 8.61e-01 9.80e+02  -0.1 6.21e+00    -  2.10e-01 7.84e-03f  1
#  262r 3.7293172e+03 8.55e-01 7.36e+02  -0.1 6.58e+00    -  5.59e-01 2.49e-01f  1
#  263r 3.6105618e+03 8.56e-01 2.27e+01  -0.1 5.68e-01    -  1.00e+00 9.69e-01f  1
#  264r 3.5821030e+03 8.56e-01 4.98e-01  -0.8 5.03e-01    -  1.00e+00 1.00e+00f  1
#  265r 3.5802761e+03 8.56e-01 3.52e+01  -2.2 1.15e-01    -  9.92e-01 7.35e-01f  1
#  266r 3.5156026e+03 8.57e-01 2.90e+01  -2.2 4.64e-02    -  6.65e-01 1.00e+00f  1
#  267r 3.5112523e+03 8.58e-01 1.62e-02  -2.2 2.11e-02    -  1.00e+00 1.00e+00f  1
#  268r 3.5227774e+03 8.57e-01 6.02e-01  -4.9 6.91e-02    -  8.77e-01 9.92e-01f  1
#  269r 3.5176632e+03 8.57e-01 1.85e-02  -4.9 1.24e-02    -  9.54e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  270r 3.5298954e+03 8.54e-01 7.35e-05  -4.9 4.77e-02    -  1.00e+00 1.00e+00H  1
#  271r 3.5301721e+03 8.54e-01 1.06e+00  -7.4 9.80e+00  -4.0 1.15e-02 6.15e-03f  1
#  272r 3.5304439e+03 8.54e-01 3.23e-02  -7.4 8.58e-03    -  9.70e-01 1.00e+00h  1
#  273r 3.5660908e+03 8.52e-01 1.99e-03  -7.4 3.07e-02    -  9.38e-01 1.00e+00h  1
#  274r 3.6068877e+03 8.60e-01 6.82e-13  -7.4 2.16e-02    -  1.00e+00 1.00e+00h  1
#  275r 3.6323579e+03 8.63e-01 1.70e-04  -9.0 1.25e-02    -  9.18e-01 1.00e+00f  1
#
# Number of Iterations....: 275
#
#                                    (scaled)                 (unscaled)
# Objective...............:   3.6347276065529813e+03    3.6347276065529813e+03
# Dual infeasibility......:   1.9268727275108211e+03    1.9268727275108211e+03
# Constraint violation....:   8.6343635374723327e-01    8.6343635374723327e-01
# Complementarity.........:   2.4316810716768209e-09    2.4316810716768209e-09
# Overall NLP error.......:   1.9268727275108211e+03    1.9268727275108211e+03
#
#
# Number of objective function evaluations             = 485
# Number of objective gradient evaluations             = 125
# Number of equality constraint evaluations            = 485
# Number of inequality constraint evaluations          = 485
# Number of equality constraint Jacobian evaluations   = 292
# Number of inequality constraint Jacobian evaluations = 292
# Number of Lagrangian Hessian evaluations             = 276
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.528
# Total CPU secs in NLP function evaluations           =      0.862
#
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.31ms (  8.88us)   4.31ms (  8.88us)       485
#        nlp_g  |  66.47ms (137.05us)  66.59ms (137.29us)       485
#     nlp_grad  | 504.00us (504.00us) 503.99us (503.99us)         1
#   nlp_grad_f  |   2.64ms ( 20.95us)   2.42ms ( 19.23us)       126
#   nlp_hess_l  | 540.39ms (  2.07ms) 539.47ms (  2.07ms)       261
#    nlp_jac_g  | 262.62ms (896.32us) 263.08ms (897.89us)       293
#        total  |   1.43 s (  1.43 s)   1.41 s (  1.41 s)         1
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-36-431a98f86f65> in <module>
#     201
#     202 #         bri.opti.subject_to(bri.x_opt[1,:] > 0.0)
# --> 203         bri.solve(None, nonresponse_u_list)
#     204         x1, u1, x1_des, _, _, _, other_x, other_u, other_des = bri.get_solution()
#     205         xothers = other_x # initialize the x values of the other vehicles
#
# ~/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/IterativeBestResponseMPCMultiple.py in solve(self, uamb, uother)
#     197         # self.opti.set_value(self.u2_opt, u2)
#     198
# --> 199         self.solution = self.opti.solve()
#     200
#     201     def get_bestresponse_solution(self):
#
# ~/anaconda3/lib/python3.7/site-packages/casadi/casadi.py in solve(self, *args)
#   27240
#   27241         """
# > 27242         return _casadi.Opti_solve(self, *args)
#   27243
#   27244
#
# RuntimeError: Error in Opti::solve [OptiNode] at .../casadi/core/optistack.cpp:159:
# .../casadi/core/optistack_internal.cpp:999: Assertion "return_success(accept_limit)" failed:
# Solver failed. You may use opti.debug.value to investigate the latest values of variables. return_status is 'Infeasible_Problem_Detected'

# %%
x_deb = bri.opti.debug.value(bri.x_opt)
x_others = [bri.opti.debug.value(bri.allother_x_opt[i]) for i in range(len(bri.allother_x_opt))]

# %%
for k in range(len(x_deb[0,:])):
    plt.plot(x_deb[0,k], x_deb[1,k], 'o')
    plt.plot(x_others[0][0,k], x_others[0][1,k],'x')
    plt.xlim([0, 50])
    plt.ylim([-1, 5])
    plt.show()

# %%
bri.opti.debug.show_infeasibilities()
# Out:
# Violated constraints (tol 0), in order of declaration:
# ------- i = 192/1326 ------
# 0 <= 24.0207 <= 0 (viol 24.0207)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 193/1326 ------
# 0 <= -8.67362e-19 <= 0 (viol 8.67362e-19)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 194/1326 ------
# 0 <= 4.91924e-15 <= 0 (viol 4.91924e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 195/1326 ------
# 0 <= 6.97359e-16 <= 0 (viol 6.97359e-16)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 196/1326 ------
# 0 <= 2.23821e-13 <= 0 (viol 2.23821e-13)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 197/1326 ------
# 0 <= -2.22045e-16 <= 0 (viol 2.22045e-16)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 198/1326 ------
# 0 <= 1.1795e-12 <= 0 (viol 1.1795e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 199/1326 ------
# 0 <= 3.46945e-18 <= 0 (viol 3.46945e-18)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 200/1326 ------
# 0 <= 1.27589e-14 <= 0 (viol 1.27589e-14)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 201/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 202/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 203/1326 ------
# 0 <= 4.44089e-16 <= 0 (viol 4.44089e-16)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 204/1326 ------
# 0 <= 2.20268e-13 <= 0 (viol 2.20268e-13)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 205/1326 ------
# 0 <= -3.04687e-14 <= 0 (viol 3.04687e-14)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 206/1326 ------
# 0 <= -6.22488e-14 <= 0 (viol 6.22488e-14)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 207/1326 ------
# 0 <= -3.46945e-18 <= 0 (viol 3.46945e-18)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 208/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 209/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 210/1326 ------
# 0 <= 2.44285e-11 <= 0 (viol 2.44285e-11)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 211/1326 ------
# 0 <= -1.12398e-11 <= 0 (viol 1.12398e-11)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 212/1326 ------
# 0 <= -9.39375e-12 <= 0 (viol 9.39375e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 213/1326 ------
# 0 <= -4.87891e-19 <= 0 (viol 4.87891e-19)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 214/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 215/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 216/1326 ------
# 0 <= 1.7684e-10 <= 0 (viol 1.7684e-10)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 217/1326 ------
# 0 <= -4.39097e-11 <= 0 (viol 4.39097e-11)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 218/1326 ------
# 0 <= -7.96413e-12 <= 0 (viol 7.96413e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 219/1326 ------
# 0 <= 8.67362e-19 <= 0 (viol 8.67362e-19)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 220/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 221/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 222/1326 ------
# 0 <= 1.33134e-10 <= 0 (viol 1.33134e-10)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 223/1326 ------
# 0 <= -2.38559e-11 <= 0 (viol 2.38559e-11)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 224/1326 ------
# 0 <= 9.38929e-12 <= 0 (viol 9.38929e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 225/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 226/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 227/1326 ------
# 0 <= -1.77636e-15 <= 0 (viol 1.77636e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 228/1326 ------
# 0 <= 6.49223e-11 <= 0 (viol 6.49223e-11)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 229/1326 ------
# 0 <= -1.5353e-11 <= 0 (viol 1.5353e-11)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 230/1326 ------
# 0 <= 1.16153e-12 <= 0 (viol 1.16153e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 231/1326 ------
# 0 <= 8.67362e-19 <= 0 (viol 8.67362e-19)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 232/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 233/1326 ------
# 0 <= 1.77636e-15 <= 0 (viol 1.77636e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 234/1326 ------
# 0 <= 1.16692e-10 <= 0 (viol 1.16692e-10)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 235/1326 ------
# 0 <= -1.50198e-11 <= 0 (viol 1.50198e-11)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 236/1326 ------
# 0 <= -4.38018e-12 <= 0 (viol 4.38018e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 237/1326 ------
# 0 <= -3.46945e-18 <= 0 (viol 3.46945e-18)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 238/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 239/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 240/1326 ------
# 0 <= 1.64952e-10 <= 0 (viol 1.64952e-10)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 241/1326 ------
# 0 <= 6.31406e-12 <= 0 (viol 6.31406e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 242/1326 ------
# 0 <= -4.3699e-12 <= 0 (viol 4.3699e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 243/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 244/1326 ------
# 0 <= -1.77636e-15 <= 0 (viol 1.77636e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 245/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 246/1326 ------
# 0 <= 6.06022e-11 <= 0 (viol 6.06022e-11)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 247/1326 ------
# 0 <= 1.09179e-11 <= 0 (viol 1.09179e-11)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 248/1326 ------
# 0 <= -4.71084e-12 <= 0 (viol 4.71084e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 249/1326 ------
# 0 <= -6.93889e-18 <= 0 (viol 6.93889e-18)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 250/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 251/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 252/1326 ------
# 0 <= 5.11093e-11 <= 0 (viol 5.11093e-11)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 253/1326 ------
# 0 <= 6.01708e-12 <= 0 (viol 6.01708e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 254/1326 ------
# 0 <= -5.41488e-11 <= 0 (viol 5.41488e-11)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 255/1326 ------
# 0 <= 6.93889e-18 <= 0 (viol 6.93889e-18)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 256/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 257/1326 ------
# 0 <= 3.55271e-15 <= 0 (viol 3.55271e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 258/1326 ------
# 0 <= 2.08651e-10 <= 0 (viol 2.08651e-10)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 259/1326 ------
# 0 <= -2.01793e-10 <= 0 (viol 2.01793e-10)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 260/1326 ------
# 0 <= -1.65224e-10 <= 0 (viol 1.65224e-10)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 261/1326 ------
# 0 <= 1.38778e-17 <= 0 (viol 1.38778e-17)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 262/1326 ------
# 0 <= 1.77636e-15 <= 0 (viol 1.77636e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 263/1326 ------
# 0 <= -3.55271e-15 <= 0 (viol 3.55271e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 264/1326 ------
# 0 <= 9.48084e-10 <= 0 (viol 9.48084e-10)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 265/1326 ------
# 0 <= -2.15679e-10 <= 0 (viol 2.15679e-10)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 266/1326 ------
# 0 <= -1.14661e-10 <= 0 (viol 1.14661e-10)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 267/1326 ------
# 0 <= -1.38778e-17 <= 0 (viol 1.38778e-17)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 268/1326 ------
# 0 <= -1.77636e-15 <= 0 (viol 1.77636e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 269/1326 ------
# 0 <= 3.55271e-15 <= 0 (viol 3.55271e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 270/1326 ------
# 0 <= 1.81357e-09 <= 0 (viol 1.81357e-09)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 271/1326 ------
# 0 <= -1.59863e-10 <= 0 (viol 1.59863e-10)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 272/1326 ------
# 0 <= -7.89654e-11 <= 0 (viol 7.89654e-11)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 273/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 274/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 275/1326 ------
# 0 <= 3.55271e-15 <= 0 (viol 3.55271e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 276/1326 ------
# 0 <= 2.68692e-09 <= 0 (viol 2.68692e-09)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 277/1326 ------
# 0 <= -3.41724e-11 <= 0 (viol 3.41724e-11)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 278/1326 ------
# 0 <= -6.90586e-11 <= 0 (viol 6.90586e-11)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 279/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 280/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero

# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:164 in add_dynamics_constraints
#   opti.subject_to(X[:,0] == x0)
# At nonzero 1.
# ------- i = 332/1326 ------
# 0 <= -5.2595e-15 <= 0 (viol 5.2595e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:164 in add_dynamics_constraints
#   opti.subject_to(X[:,0] == x0)
# At nonzero 2.
# ------- i = 333/1326 ------
# 0 <= -3.86026e-16 <= 0 (viol 3.86026e-16)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:164 in add_dynamics_constraints
#   opti.subject_to(X[:,0] == x0)
# At nonzero 3.
# ------- i = 334/1326 ------
# 8.38125 <= 8.38125 <= 8.38125 (viol 1.30207e-12)
# ...
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 967/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 968/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 969/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 970/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 971/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 972/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 973/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 974/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 975/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 976/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 977/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 978/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 979/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 980/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 981/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 982/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 983/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 984/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 985/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 986/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 987/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 988/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 989/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 990/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 991/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 992/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 993/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 994/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 995/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 996/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 997/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 998/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 999/1326 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:159 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 1000/1326 ------
# 19.1823 <= 19.1823 <= 19.1823 (viol 3.32889e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:164 in add_dynamics_constraints
#   opti.subject_to(X[:,0] == x0)
# At nonzero 0.
# ------- i = 1001/1326 ------
# 3.7 <= 3.7 <= 3.7 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:164 in add_dynamics_constraints
#   opti.subject_to(X[:,0] == x0)
# At nonzero 1.
# ------- i = 1002/1326 ------
# 0 <= -2.77043e-18 <= 0 (viol 2.77043e-18)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:164 in add_dynamics_constraints
#   opti.subject_to(X[:,0] == x0)
# At nonzero 2.
# ------- i = 1003/1326 ------
# 0 <= -5.37916e-18 <= 0 (viol 5.37916e-18)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:164 in add_dynamics_constraints
#   opti.subject_to(X[:,0] == x0)
# At nonzero 3.
# ------- i = 1004/1326 ------
# 8.38125 <= 8.38125 <= 8.38125 (viol 6.21725e-13)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:164 in add_dynamics_constraints
#   opti.subject_to(X[:,0] == x0)
# At nonzero 4.
# ------- i = 1005/1326 ------
# 0 <= -1.00167e-16 <= 0 (viol 1.00167e-16)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:164 in add_dynamics_constraints
#   opti.subject_to(X[:,0] == x0)
# At nonzero 5.
# ------- i = 1016/1326 ------
# -inf <= 0.0824468 <= 0 (viol 0.0824468)
# Opti constraint of shape 1x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/IterativeBestResponseMPCMultiple.py:233 in generate_collision_ellipse
#   self.opti.subject_to(prod > (1 - slack))
# ------- i = 1017/1326 ------
# -inf <= 0.0824466 <= 0 (viol 0.0824466)
# Opti constraint of shape 1x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/IterativeBestResponseMPCMultiple.py:233 in generate_collision_ellipse
#   self.opti.subject_to(prod > (1 - slack))
# ------- i = 1024/1326 ------
# -inf <= 9.99241e-09 <= 0 (viol 9.99241e-09)
# Opti constraint of shape 1x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/IterativeBestResponseMPCMultiple.py:233 in generate_collision_ellipse
#   self.opti.subject_to(prod > (1 - slack))
# ------- i = 1025/1326 ------
# -inf <= 9.99241e-09 <= 0 (viol 9.99241e-09)
# Opti constraint of shape 1x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/IterativeBestResponseMPCMultiple.py:233 in generate_collision_ellipse
#   self.opti.subject_to(prod > (1 - slack))
# ------- i = 1233/1326 ------
# -inf <= 0.113204 <= 0.1 (viol 0.0132037)
# Opti constraint of shape 48x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/python_experiments/<ipython-input-28-2669d98d099d>:195
# At nonzero 3.
# ------- i = 1236/1326 ------
# -inf <= 0.1 <= 0.1 (viol 9.99241e-09)
# Opti constraint of shape 48x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/python_experiments/<ipython-input-28-2669d98d099d>:195
# At nonzero 6.
# ------- i = 1281/1326 ------
# -inf <= 0.113204 <= 0.1 (viol 0.0132038)
# Opti constraint of shape 48x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/python_experiments/<ipython-input-28-2669d98d099d>:195
# At nonzero 3.
# ------- i = 1284/1326 ------
# -inf <= 0.1 <= 0.1 (viol 9.99241e-09)
# Opti constraint of shape 48x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/python_experiments/<ipython-input-28-2669d98d099d>:195
# At nonzero 6.

# %%
xamb = bri.opti.debug.value(bri.x_opt)
xothers = [bri.opti.debug.value(bri.allother_x_opt[i]) for i in range(n_other)]

# %%
plt.plot(xamb[0,:], xamb[1,:])
for i in range(n_other):
    plt.plot(xothers[i][0,:], xothers[i][1,:])
plt.ylim([0, 10])
# Out:
# (0, 10)

# %%
x1_MPC.f(actual_xothers[0][:,0], actual_uothers[0][:,0])

# %%
x1_MPC.F_kutta(x1_MPC.f, actual_xothers[0][:,0], actual_uothers[0][:,0])

# %%
actual_xothers[0][:,1]

# %%
plt.plot(actual_uothers[0][0,:10],'o')

# %%
x0_amb[2]

# %%
print(bri.opti.debug.value(bri.x_opt[0,:]))
for i in range(n_other):
    print(bri.opti.debug.value(bri.allother_x_opt[i][0,:]))
# Out:
# [ 8.91 10.87 12.98 15.26 17.69 20.29 23.03 25.84 28.63 31.35 33.94 36.4
#  38.72 40.9  42.98 44.98]
# [17.97 19.65 21.32 23.   24.68 26.35 28.03 29.7  31.38 33.05 34.73 36.4
#  38.08 39.75 41.43 43.1 ]
# [ 5.24  6.91  8.59 10.27 11.94 13.62 15.29 16.97 18.65 20.32 22.   23.67
#  25.35 27.02 28.69 30.37]

# %%
bri.opti.debug.show_infeasibilities()
# Out:
# Violated constraints (tol 0), in order of declaration:
# ------- i = 96/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 97/846 ------
# 0 <= -4.33681e-19 <= 0 (viol 4.33681e-19)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 98/846 ------
# 0 <= -4.33681e-19 <= 0 (viol 4.33681e-19)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 99/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 100/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 101/846 ------
# 0 <= -1.77636e-15 <= 0 (viol 1.77636e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 102/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 103/846 ------
# 0 <= -3.46945e-18 <= 0 (viol 3.46945e-18)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 104/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 105/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 106/846 ------
# 0 <= 1.77636e-15 <= 0 (viol 1.77636e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 107/846 ------
# 0 <= 1.77636e-15 <= 0 (viol 1.77636e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 108/846 ------
# 0 <= 3.19744e-14 <= 0 (viol 3.19744e-14)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 109/846 ------
# 0 <= 5.66214e-15 <= 0 (viol 5.66214e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 110/846 ------
# 0 <= 1.26635e-14 <= 0 (viol 1.26635e-14)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 111/846 ------
# 0 <= 1.38778e-17 <= 0 (viol 1.38778e-17)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 112/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 113/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 114/846 ------
# 0 <= 6.32383e-13 <= 0 (viol 6.32383e-13)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 115/846 ------
# 0 <= 1.28508e-14 <= 0 (viol 1.28508e-14)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 116/846 ------
# 0 <= 3.42365e-14 <= 0 (viol 3.42365e-14)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 117/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 118/846 ------
# 0 <= 1.77636e-15 <= 0 (viol 1.77636e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 119/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 120/846 ------
# 0 <= 2.68585e-12 <= 0 (viol 2.68585e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 121/846 ------
# 0 <= -1.4394e-13 <= 0 (viol 1.4394e-13)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 122/846 ------
# 0 <= 1.90958e-14 <= 0 (viol 1.90958e-14)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 123/846 ------
# 0 <= -1.73472e-18 <= 0 (viol 1.73472e-18)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 124/846 ------
# 0 <= -1.77636e-15 <= 0 (viol 1.77636e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 125/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 126/846 ------
# 0 <= 6.63647e-12 <= 0 (viol 6.63647e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 127/846 ------
# 0 <= -6.9067e-13 <= 0 (viol 6.9067e-13)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 128/846 ------
# 0 <= -2.38004e-14 <= 0 (viol 2.38004e-14)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 129/846 ------
# 0 <= 8.67362e-19 <= 0 (viol 8.67362e-19)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 130/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 131/846 ------
# 0 <= 3.55271e-15 <= 0 (viol 3.55271e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 132/846 ------
# 0 <= 1.24452e-11 <= 0 (viol 1.24452e-11)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 133/846 ------
# 0 <= -1.52955e-12 <= 0 (viol 1.52955e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 134/846 ------
# 0 <= -7.11028e-14 <= 0 (viol 7.11028e-14)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 135/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 136/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 137/846 ------
# 0 <= -3.55271e-15 <= 0 (viol 3.55271e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 138/846 ------
# 0 <= 1.88258e-11 <= 0 (viol 1.88258e-11)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 139/846 ------
# 0 <= -2.02693e-12 <= 0 (viol 2.02693e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 140/846 ------
# 0 <= -7.29208e-14 <= 0 (viol 7.29208e-14)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 141/846 ------
# 0 <= 6.93889e-18 <= 0 (viol 6.93889e-18)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 142/846 ------
# 0 <= 1.77636e-15 <= 0 (viol 1.77636e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 143/846 ------
# 0 <= 3.55271e-15 <= 0 (viol 3.55271e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 144/846 ------
# 0 <= 1.78737e-11 <= 0 (viol 1.78737e-11)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 145/846 ------
# 0 <= -1.76537e-12 <= 0 (viol 1.76537e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 146/846 ------
# 0 <= -5.07493e-14 <= 0 (viol 5.07493e-14)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 147/846 ------
# 0 <= -6.93889e-18 <= 0 (viol 6.93889e-18)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 148/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 149/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 150/846 ------
# 0 <= 5.94724e-12 <= 0 (viol 5.94724e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 151/846 ------
# 0 <= -3.30391e-12 <= 0 (viol 3.30391e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 152/846 ------
# 0 <= -4.61556e-12 <= 0 (viol 4.61556e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 153/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 154/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 155/846 ------
# 0 <= 7.10543e-15 <= 0 (viol 7.10543e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 156/846 ------
# 0 <= 7.53033e-11 <= 0 (viol 7.53033e-11)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 157/846 ------
# 0 <= 1.79201e-12 <= 0 (viol 1.79201e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 158/846 ------
# 0 <= -3.74266e-12 <= 0 (viol 3.74266e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 159/846 ------
# 0 <= -1.38778e-17 <= 0 (viol 1.38778e-17)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 160/846 ------
# 0 <= -1.77636e-15 <= 0 (viol 1.77636e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 161/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 162/846 ------
# 0 <= 1.01693e-10 <= 0 (viol 1.01693e-10)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 163/846 ------
# 0 <= 1.54051e-11 <= 0 (viol 1.54051e-11)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 164/846 ------
# 0 <= -6.81705e-13 <= 0 (viol 6.81705e-13)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 165/846 ------
# 0 <= 1.38778e-17 <= 0 (viol 1.38778e-17)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 166/846 ------
# 0 <= 1.77636e-15 <= 0 (viol 1.77636e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 167/846 ------
# 0 <= 7.10543e-15 <= 0 (viol 7.10543e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 168/846 ------
# 0 <= 5.23741e-11 <= 0 (viol 5.23741e-11)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 169/846 ------
# 0 <= 8.77098e-12 <= 0 (viol 8.77098e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 170/846 ------
# 0 <= -2.98969e-12 <= 0 (viol 2.98969e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 171/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 172/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 173/846 ------
# 0 <= -7.10543e-15 <= 0 (viol 7.10543e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 174/846 ------
# 0 <= 1.1255e-11 <= 0 (viol 1.1255e-11)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 175/846 ------
# 0 <= 1.66353e-13 <= 0 (viol 1.66353e-13)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 176/846 ------
# 0 <= -3.78866e-12 <= 0 (viol 3.78866e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 177/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 178/846 ------
# 0 <= -1.77636e-15 <= 0 (viol 1.77636e-15)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 179/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 180/846 ------
# 0 <= 2.92033e-12 <= 0 (viol 2.92033e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 0.
# ------- i = 181/846 ------
# 0 <= -4.01806e-12 <= 0 (viol 4.01806e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 1.
# ------- i = 182/846 ------
# 0 <= -3.69232e-12 <= 0 (viol 3.69232e-12)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 2.
# ------- i = 183/846 ------
# 0 <= -1.38778e-17 <= 0 (viol 1.38778e-17)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 3.
# ------- i = 184/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 4.
# ------- i = 185/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:153 in add_dynamics_constraints
#   opti.subject_to( X[:, k+1] == self.F_kutta(self.f, X[:, k], U[:, k]))
# At nonzero 5.
# ------- i = 186/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 187/846 ------
# 0 <= -2.30417e-29 <= 0 (viol 2.30417e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 188/846 ------
# 0 <= 2.90217e-29 <= 0 (viol 2.90217e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 189/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 190/846 ------
# 0 <= -4.21001e-29 <= 0 (viol 4.21001e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 191/846 ------
# 0 <= -3.09801e-29 <= 0 (viol 3.09801e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 192/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 193/846 ------
# 0 <= 3.91367e-29 <= 0 (viol 3.91367e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 194/846 ------
# 0 <= 3.22733e-30 <= 0 (viol 3.22733e-30)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 195/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 196/846 ------
# 0 <= 1.35893e-29 <= 0 (viol 1.35893e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 197/846 ------
# 0 <= 1.42598e-29 <= 0 (viol 1.42598e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 198/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 199/846 ------
# 0 <= 1.07631e-29 <= 0 (viol 1.07631e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 200/846 ------
# 0 <= 4.45026e-29 <= 0 (viol 4.45026e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 201/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 202/846 ------
# 0 <= 1.87866e-29 <= 0 (viol 1.87866e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 203/846 ------
# 0 <= 3.61842e-29 <= 0 (viol 3.61842e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 204/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 205/846 ------
# 0 <= 4.10666e-29 <= 0 (viol 4.10666e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 206/846 ------
# 0 <= -2.23791e-29 <= 0 (viol 2.23791e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 207/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 208/846 ------
# 0 <= 2.04186e-29 <= 0 (viol 2.04186e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 209/846 ------
# 0 <= 3.5913e-29 <= 0 (viol 3.5913e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 210/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 211/846 ------
# 0 <= 4.09429e-29 <= 0 (viol 4.09429e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 212/846 ------
# 0 <= -1.21646e-29 <= 0 (viol 1.21646e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 213/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 214/846 ------
# 0 <= -4.44699e-29 <= 0 (viol 4.44699e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 215/846 ------
# 0 <= -4.11271e-29 <= 0 (viol 4.11271e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 216/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 217/846 ------
# 0 <= 7.96603e-30 <= 0 (viol 7.96603e-30)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 218/846 ------
# 0 <= -4.78079e-29 <= 0 (viol 4.78079e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 219/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 220/846 ------
# 0 <= -1.51895e-29 <= 0 (viol 1.51895e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 221/846 ------
# 0 <= -4.58113e-29 <= 0 (viol 4.58113e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 222/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 223/846 ------
# 0 <= 1.84886e-29 <= 0 (viol 1.84886e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 224/846 ------
# 0 <= -1.85487e-29 <= 0 (viol 1.85487e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 225/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 226/846 ------
# 0 <= 3.4877e-29 <= 0 (viol 3.4877e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 227/846 ------
# 0 <= -3.67048e-29 <= 0 (viol 3.67048e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 228/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 229/846 ------
# 0 <= -4.43692e-29 <= 0 (viol 4.43692e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 230/846 ------
# 0 <= -2.79203e-29 <= 0 (viol 2.79203e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 231/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 232/846 ------
# 0 <= 3.03542e-29 <= 0 (viol 3.03542e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 233/846 ------
# 0 <= -1.04122e-29 <= 0 (viol 1.04122e-29)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 234/846 ------
# 8.90869 <= 8.90879 <= 8.90869 (viol 9.38481e-05)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:161 in add_dynamics_constraints
#   opti.subject_to(X[:,0] == x0)
# At nonzero 0.
# ------- i = 235/846 ------
# -5.43701e-09 <= -5.43695e-09 <= -5.43701e-09 (viol 5.33755e-14)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:161 in add_dynamics_constraints
#   opti.subject_to(X[:,0] == x0)
# At nonzero 1.
# ------- i = 236/846 ------
# -1.26819e-09 <= -1.26824e-09 <= -1.26819e-09 (viol 4.8031e-14)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:161 in add_dynamics_constraints
#   opti.subject_to(X[:,0] == x0)
# At nonzero 2.
# ------- i = 237/846 ------
# -5.44172e-10 <= -5.44172e-10 <= -5.44172e-10 (viol 7.08085e-19)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:161 in add_dynamics_constraints
#   opti.subject_to(X[:,0] == x0)
# At nonzero 3.
# ------- i = 238/846 ------
# 9.38672 <= 9.38672 <= 9.38672 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:161 in add_dynamics_constraints
#   opti.subject_to(X[:,0] == x0)
# At nonzero 4.
# ------- i = 239/846 ------
# ...
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 578/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 579/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 580/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 581/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 582/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 583/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 584/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 585/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 586/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 587/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 588/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 589/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 590/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 591/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 592/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 593/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 594/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 595/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 596/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 597/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 598/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 599/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 600/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 601/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 602/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 603/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 604/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 605/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 606/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 607/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 608/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 609/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 610/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 611/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 612/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 613/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 0.
# ------- i = 614/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 1.
# ------- i = 615/846 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 3x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:156 in add_dynamics_constraints
#   opti.subject_to( X_desired[:, k] == self.fd(X[-1, k]) ) #This should be the trajectory dynamic constraint
# At nonzero 2.
# ------- i = 616/846 ------
# 17.9722 <= 5.23882 <= 17.9722 (viol 12.7334)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:161 in add_dynamics_constraints
#   opti.subject_to(X[:,0] == x0)
# At nonzero 0.
# ------- i = 617/846 ------
# -0.0443182 <= -0.0443182 <= -0.0443182 (viol 5.3374e-14)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:161 in add_dynamics_constraints
#   opti.subject_to(X[:,0] == x0)
# At nonzero 1.
# ------- i = 618/846 ------
# -0.0117026 <= -0.0117026 <= -0.0117026 (viol 6.72292e-14)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:161 in add_dynamics_constraints
#   opti.subject_to(X[:,0] == x0)
# At nonzero 2.
# ------- i = 619/846 ------
# -0.00698132 <= -0.00698132 <= -0.00698132 (viol 1.04083e-17)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:161 in add_dynamics_constraints
#   opti.subject_to(X[:,0] == x0)
# At nonzero 3.
# ------- i = 620/846 ------
# 8.38125 <= 8.38125 <= 8.38125 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:161 in add_dynamics_constraints
#   opti.subject_to(X[:,0] == x0)
# At nonzero 4.
# ------- i = 621/846 ------
# 8.38125 <= 8.38125 <= 8.38125 (viol 0)
# Opti constraint of shape 6x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/MPC_Casadi.py:161 in add_dynamics_constraints
#   opti.subject_to(X[:,0] == x0)
# At nonzero 5.
# ------- i = 625/846 ------
# -inf <= 9.99712e-09 <= 0 (viol 9.99712e-09)
# Opti constraint of shape 1x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/src/IterativeBestResponseMPCMultiple.py:118 in generate_optimization
#   self.opti.subject_to(dist_sqr - (response_radius + other_radius)**2 > 0 - self.slack_vars_list[i][ci,k])
# ------- i = 799/846 ------
# -inf <= 5.5 <= 5.5 (viol 5.49971e-08)
# Opti constraint of shape 48x1, defined at /home/nbuckman/Dropbox (MIT)/DRL/2020_01_cooperative_mpc/mpc-multiple-vehicles/python_experiments/<ipython-input-13-4216d9bb200e>:161
# At nonzero 1.
